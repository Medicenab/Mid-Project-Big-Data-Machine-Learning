# %%
import pandas as pd
from pymongo import MongoClient
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
url = os.getenv("url")

# %%
url
# Out:
# 'mongodb+srv://admin:admin@bcn.e0wqq.mongodb.net/test'

# %%
client = MongoClient(url)

# %%
client
# Out:
# MongoClient(host=['bcn-shard-00-01.e0wqq.mongodb.net:27017', 'bcn-shard-00-02.e0wqq.mongodb.net:27017', 'bcn-shard-00-00.e0wqq.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-lbgrvb-shard-0', tls=True)

# %%
db = client.get_database("BCN")

# %%
db
# Out:
# Database(MongoClient(host=['bcn-shard-00-01.e0wqq.mongodb.net:27017', 'bcn-shard-00-02.e0wqq.mongodb.net:27017', 'bcn-shard-00-00.e0wqq.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-lbgrvb-shard-0', tls=True), 'BCN')

# %%
inm_nat= list(db["INM.NATIONALITY"].find({}))
data_inm_nat= pd.DataFrame(data = inm_nat)

# %%
data_inm_nat
# Out:
#                             _id  Year District Code District Name  \
# 0      628d907528360e0bbf01e184  2017             1  Ciutat Vella
# 1      628d907528360e0bbf01e185  2017             1  Ciutat Vella
# 2      628d907528360e0bbf01e186  2017             1  Ciutat Vella
# 3      628d907528360e0bbf01e187  2017             1  Ciutat Vella
# 4      628d907528360e0bbf01e188  2017             2      Eixample
# ...                         ...   ...           ...           ...
# 35219  628d908d28360e0bbf026b17  2015            10    Sant Martí
# 35220  628d908d28360e0bbf026b18  2015            10    Sant Martí
# 35221  628d908d28360e0bbf026b19  2015            10    Sant Martí
# 35222  628d908d28360e0bbf026b1a  2015            10    Sant Martí
# 35223  628d908d28360e0bbf026b1b  2015            99     No consta
#
#       Neighborhood Code                      Neighborhood Name  \
# 0                     1                               el Raval
# 1                     2                         el Barri Gòtic
# 2                     3                         la Barceloneta
# 3                     4  Sant Pere, Santa Caterina i la Ribera
# 4                     5                          el Fort Pienc
# ...                 ...                                    ...
# 35219                70                  el Besòs i el Maresme
# 35220                71                Provençals del Poblenou
# 35221                72               Sant Martí de Provençals
# 35222                73                    la Verneda i la Pau
# 35223                99                              No consta
#
#           Nationality  Number
# 0               Spain    1109
# 1               Spain     482
# 2               Spain     414
# 3               Spain     537
# 4               Spain     663
# ...               ...     ...
# 35219  No information       0
# 35220  No information       0
# 35221  No information       0
# 35222  No information       1
# 35223  No information       0
#
# [35224 rows x 8 columns]

# %%
data_inm_nat.head(20)
# Out:
#                          _id  Year District Code   District Name  \
# 0   628d907528360e0bbf01e184  2017             1    Ciutat Vella
# 1   628d907528360e0bbf01e185  2017             1    Ciutat Vella
# 2   628d907528360e0bbf01e186  2017             1    Ciutat Vella
# 3   628d907528360e0bbf01e187  2017             1    Ciutat Vella
# 4   628d907528360e0bbf01e188  2017             2        Eixample
# 5   628d907528360e0bbf01e189  2017             2        Eixample
# 6   628d907528360e0bbf01e18a  2017             2        Eixample
# 7   628d907528360e0bbf01e18b  2017             2        Eixample
# 8   628d907528360e0bbf01e18c  2017             2        Eixample
# 9   628d907528360e0bbf01e18d  2017             2        Eixample
# 10  628d907528360e0bbf01e18e  2017             3  Sants-Montjuïc
# 11  628d907528360e0bbf01e18f  2017             3  Sants-Montjuïc
# 12  628d907528360e0bbf01e190  2017             3  Sants-Montjuïc
# 13  628d907528360e0bbf01e191  2017             3  Sants-Montjuïc
# 14  628d907528360e0bbf01e192  2017             3  Sants-Montjuïc
# 15  628d907528360e0bbf01e193  2017             3  Sants-Montjuïc
# 16  628d907528360e0bbf01e194  2017             3  Sants-Montjuïc
# 17  628d907528360e0bbf01e195  2017             3  Sants-Montjuïc
# 18  628d907528360e0bbf01e196  2017             4       Les Corts
# 19  628d907528360e0bbf01e197  2017             4       Les Corts
#
#    Neighborhood Code                      Neighborhood Name Nationality  \
# 0                  1                               el Raval       Spain
# 1                  2                         el Barri Gòtic       Spain
# 2                  3                         la Barceloneta       Spain
# 3                  4  Sant Pere, Santa Caterina i la Ribera       Spain
# 4                  5                          el Fort Pienc       Spain
# 5                  6                     la Sagrada Família       Spain
# 6                  7                 la Dreta de l'Eixample       Spain
# 7                  8        l'Antiga Esquerra de l'Eixample       Spain
# 8                  9         la Nova Esquerra de l'Eixample       Spain
# 9                 10                            Sant Antoni       Spain
# 10                11                           el Poble Sec       Spain
# 11                12             la Marina del Prat Vermell       Spain
# 12                13                      la Marina de Port       Spain
# 13                14                  la Font de la Guatlla       Spain
# 14                15                            Hostafrancs       Spain
# 15                16                             la Bordeta       Spain
# 16                17                          Sants - Badal       Spain
# 17                18                                  Sants       Spain
# 18                19                              les Corts       Spain
# 19                20             la Maternitat i Sant Ramon       Spain
#
#     Number
# 0     1109
# 1      482
# 2      414
# 3      537
# 4      663
# 5     1181
# 6     1063
# 7     1177
# 8     1593
# 9      883
# 10     826
# 11      23
# 12     574
# 13     264
# 14     410
# 15     434
# 16     605
# 17    1083
# 18    1027
# 19     630

# %%
print(data_inm_nat['Nationality'].unique())
# Out:
# ['Spain' 'Italy' 'China' 'Colombia' 'Venezuela' 'Pakistan' 'Honduras'
#  'France' 'Peru' 'Morocco' 'Argentina' 'Brasil' 'United States'
#  'United Kingdom' 'India' 'Ecuador' 'Russia' 'Germany'
#  'Dominican Republic' 'Mexico' 'Romania' 'Chile' 'Bolivia' 'Portugal'
#  'Ukraine' 'Bangladesh' 'Philippines' 'Paraguay' 'Georgia' 'Netherlands'
#  'Cuba' 'Poland' 'El Salvador' 'Turkey' 'Iran' 'Japan' 'Uruguay' 'Sweden'
#  'Nepal' 'Armenia' 'Belgium' 'Bulgaria' 'Algeria' 'South Korea'
#  'Nicaragua' 'Canada' 'Senegal' 'Switzerland' 'Greece' 'Ireland'
#  'Costa Rica' 'Hungary' 'Egypt' 'Panama' 'Lebanon' 'Nigeria' 'Guatemala'
#  'Israel' 'Austria' 'Denmark' 'Finland' 'Kazakhstan' 'Lithuania' 'Syria'
#  'Vietnam' 'Albania' 'Belarus' 'Australia' 'Czech Republic' 'Croatia'
#  'Equatorial Guinea' 'Serbia' 'Slovakia' 'Norway' 'Tunisia' 'Ghana'
#  'Latvia' 'Moldova' 'Andorra' 'South Africa' 'Slovenia' 'Gambia' 'Camerun'
#  'Indonesia' 'Jordan' 'Azerbaijan' 'Estonia' 'Guinea' 'Iraq'
#  'Saudi Arabia' 'State of Palestine' 'Uzbekistan' 'Cyprus' 'Iceland'
#  'Libya' 'Thailand' 'Mali' 'New Zealand' 'Afghanistan' 'Macedonia'
#  'Angola' 'Ivory Coast' 'Kenya' 'Malaysia' 'Mongolia'
#  'Bosnia and Herzegovina' 'Singapore' 'Luxembourg' 'Sudan' 'Guinea-Bissau'
#  'Tanzania' 'Dominica' 'Kyrgyzstan' 'Congo' 'Mauritania' 'Malta' 'Kuwait'
#  'Montenegro' 'Mozambique' 'Uganda' 'Benin' 'Haiti' 'Trinidad and Tobago'
#  'Myanmar' 'Ethiopia' 'Mauritius' 'Namibia' 'Sierra Leone' 'Qatar'
#  'Sri Lanka' 'Burkina Faso' 'Malawi' 'Togo' 'Eritrea'
#  'United Arab Emirates' 'Cambodja' 'Turkmenistan' 'Chad' 'Zimbabwe'
#  'Botswana' 'Gabon' 'Madagascar' 'Niger' 'Somalia' 'Zambia' 'The Bahamas'
#  'Jamaica' 'Yemen' 'Cape Verde' 'São Tomé and Príncipe'
#  'Antigua and Barbuda' 'Barbados' 'Grenada' 'Bahrain' 'Laos' 'Maldives'
#  'Oman' 'Solomon Islands' 'No information' 'Burundi'
#  'Central African Republic' 'North Korea' 'Guyana' 'Lesotho' 'Liberia'
#  'Puerto Rico' 'Rwanda' 'Saint Kitts and Nevis' 'San Marino' 'Seychelles'
#  'Suriname' 'Tajikistan' 'East Timor' 'Palestinian territories' 'Djibouti'
#  'Swaziland' 'Taiwan']

# %%
data_inm_nat = data_inm_nat.drop(columns=["_id","Neighborhood Code","District Code"])

# %%
data_inm_nat.isnull().sum()
# Out:
# Year                 0
# District Name        0
# Neighborhood Name    0
# Nationality          0
# Number               0
# dtype: int64

# %%
type(data_inm_nat["Nationality"])
# Out:
# pandas.core.series.Series

# %%
data_inm_nat["Nationality"]=="No information"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 35219     True
# 35220     True
# 35221     True
# 35222     True
# 35223     True
# Name: Nationality, Length: 35224, dtype: bool

# %%
data_inm_nat[data_inm_nat["Nationality"]=="No information"]
# Out:
#        Year District Name                      Neighborhood Name  \
# 11692  2017  Ciutat Vella                               el Raval
# 11693  2017  Ciutat Vella                         el Barri Gòtic
# 11694  2017  Ciutat Vella                         la Barceloneta
# 11695  2017  Ciutat Vella  Sant Pere, Santa Caterina i la Ribera
# 11696  2017      Eixample                          el Fort Pienc
# ...     ...           ...                                    ...
# 35219  2015    Sant Martí                  el Besòs i el Maresme
# 35220  2015    Sant Martí                Provençals del Poblenou
# 35221  2015    Sant Martí               Sant Martí de Provençals
# 35222  2015    Sant Martí                    la Verneda i la Pau
# 35223  2015     No consta                              No consta
#
#           Nationality  Number
# 11692  No information       2
# 11693  No information       1
# 11694  No information       0
# 11695  No information       0
# 11696  No information       2
# ...               ...     ...
# 35219  No information       0
# 35220  No information       0
# 35221  No information       0
# 35222  No information       1
# 35223  No information       0
#
# [222 rows x 5 columns]

# %%
data_inm_nat.drop(data_inm_nat[data_inm_nat["Nationality"]=="No information"].index, inplace=True)

# %%
data_inm_nat[data_inm_nat["District Name"]=="No consta"]
# Out:
#        Year District Name Neighborhood Name          Nationality  Number
# 73     2017     No consta         No consta                Spain       2
# 147    2017     No consta         No consta                Italy       0
# 221    2017     No consta         No consta                China       0
# 295    2017     No consta         No consta             Colombia       0
# 369    2017     No consta         No consta            Venezuela       0
# ...     ...           ...               ...                  ...     ...
# 34853  2015     No consta         No consta           Seychelles       0
# 34927  2015     No consta         No consta         Sierra Leone       0
# 35001  2015     No consta         No consta            Swaziland       0
# 35075  2015     No consta         No consta               Taiwan       0
# 35149  2015     No consta         No consta  Trinidad and Tobago       0
#
# [473 rows x 5 columns]

# %%
data_inm_nat.drop(data_inm_nat[data_inm_nat["District Name"]=="No consta"].index, inplace=True)

# %%
data_inm_nat
# Out:
#        Year District Name                             Neighborhood Name  \
# 0      2017  Ciutat Vella                                      el Raval
# 1      2017  Ciutat Vella                                el Barri Gòtic
# 2      2017  Ciutat Vella                                la Barceloneta
# 3      2017  Ciutat Vella         Sant Pere, Santa Caterina i la Ribera
# 4      2017      Eixample                                 el Fort Pienc
# ...     ...           ...                                           ...
# 35144  2015    Sant Martí  Diagonal Mar i el Front Marítim del Poblenou
# 35145  2015    Sant Martí                         el Besòs i el Maresme
# 35146  2015    Sant Martí                       Provençals del Poblenou
# 35147  2015    Sant Martí                      Sant Martí de Provençals
# 35148  2015    Sant Martí                           la Verneda i la Pau
#
#                Nationality  Number
# 0                    Spain    1109
# 1                    Spain     482
# 2                    Spain     414
# 3                    Spain     537
# 4                    Spain     663
# ...                    ...     ...
# 35144  Trinidad and Tobago       0
# 35145  Trinidad and Tobago       0
# 35146  Trinidad and Tobago       0
# 35147  Trinidad and Tobago       0
# 35148  Trinidad and Tobago       0
#
# [34529 rows x 5 columns]

# %%
data_inm_nat
# Out:
#        Year   District Name                             Neighborhood Name  \
# 85     2017  Sants-Montjuïc                    la Marina del Prat Vermell
# 120    2017      Nou Barris                                   Can Peguera
# 127    2017      Nou Barris                                    Torre Baró
# 176    2017          Gràcia                                       el Coll
# 189    2017  Horta-Guinardó                                      la Clota
# ...     ...             ...                                           ...
# 35144  2015      Sant Martí  Diagonal Mar i el Front Marítim del Poblenou
# 35145  2015      Sant Martí                         el Besòs i el Maresme
# 35146  2015      Sant Martí                       Provençals del Poblenou
# 35147  2015      Sant Martí                      Sant Martí de Provençals
# 35148  2015      Sant Martí                           la Verneda i la Pau
#
#                Nationality  Number
# 85                   Italy       0
# 120                  Italy       0
# 127                  Italy       0
# 176                  China       0
# 189                  China       0
# ...                    ...     ...
# 35144  Trinidad and Tobago       0
# 35145  Trinidad and Tobago       0
# 35146  Trinidad and Tobago       0
# 35147  Trinidad and Tobago       0
# 35148  Trinidad and Tobago       0
#
# [20955 rows x 5 columns]

# %%
inm_nat
# Out:
# [{'_id': ObjectId('628d907528360e0bbf01e184'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '1',
#   'Neighborhood Name': 'el Raval',
#   'Nationality': 'Spain',
#   'Number': 1109},
#  {'_id': ObjectId('628d907528360e0bbf01e185'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '2',
#   'Neighborhood Name': 'el Barri Gòtic',
#   'Nationality': 'Spain',
#   'Number': 482},
#  {'_id': ObjectId('628d907528360e0bbf01e186'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '3',
#   'Neighborhood Name': 'la Barceloneta',
#   'Nationality': 'Spain',
#   'Number': 414},
#  {'_id': ObjectId('628d907528360e0bbf01e187'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '4',
#   'Neighborhood Name': 'Sant Pere, Santa Caterina i la Ribera',
#   'Nationality': 'Spain',
#   'Number': 537},
#  {'_id': ObjectId('628d907528360e0bbf01e188'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '5',
#   'Neighborhood Name': 'el Fort Pienc',
#   'Nationality': 'Spain',
#   'Number': 663},
#  {'_id': ObjectId('628d907528360e0bbf01e189'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '6',
#   'Neighborhood Name': 'la Sagrada Família',
#   'Nationality': 'Spain',
#   'Number': 1181},
#  {'_id': ObjectId('628d907528360e0bbf01e18a'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '7',
#   'Neighborhood Name': "la Dreta de l'Eixample",
#   'Nationality': 'Spain',
#   'Number': 1063},
#  {'_id': ObjectId('628d907528360e0bbf01e18b'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '8',
#   'Neighborhood Name': "l'Antiga Esquerra de l'Eixample",
#   'Nationality': 'Spain',
#   'Number': 1177},
#  {'_id': ObjectId('628d907528360e0bbf01e18c'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '9',
#   'Neighborhood Name': "la Nova Esquerra de l'Eixample",
#   'Nationality': 'Spain',
#   'Number': 1593},
#  {'_id': ObjectId('628d907528360e0bbf01e18d'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '10',
#   'Neighborhood Name': 'Sant Antoni',
#   'Nationality': 'Spain',
#   'Number': 883},
#  {'_id': ObjectId('628d907528360e0bbf01e18e'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '11',
#   'Neighborhood Name': 'el Poble Sec',
#   'Nationality': 'Spain',
#   'Number': 826},
#  {'_id': ObjectId('628d907528360e0bbf01e18f'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '12',
#   'Neighborhood Name': 'la Marina del Prat Vermell',
#   'Nationality': 'Spain',
#   'Number': 23},
#  {'_id': ObjectId('628d907528360e0bbf01e190'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '13',
#   'Neighborhood Name': 'la Marina de Port',
#   'Nationality': 'Spain',
#   'Number': 574},
#  {'_id': ObjectId('628d907528360e0bbf01e191'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '14',
#   'Neighborhood Name': 'la Font de la Guatlla',
#   'Nationality': 'Spain',
#   'Number': 264},
#  {'_id': ObjectId('628d907528360e0bbf01e192'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '15',
#   'Neighborhood Name': 'Hostafrancs',
#   'Nationality': 'Spain',
#   'Number': 410},
#  {'_id': ObjectId('628d907528360e0bbf01e193'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '16',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'Spain',
#   'Number': 434},
#  {'_id': ObjectId('628d907528360e0bbf01e194'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '17',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'Spain',
#   'Number': 605},
#  {'_id': ObjectId('628d907528360e0bbf01e195'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '18',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'Spain',
#   'Number': 1083},
#  {'_id': ObjectId('628d907528360e0bbf01e196'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '19',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'Spain',
#   'Number': 1027},
#  {'_id': ObjectId('628d907528360e0bbf01e197'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '20',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'Spain',
#   'Number': 630},
#  {'_id': ObjectId('628d907528360e0bbf01e198'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '21',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'Spain',
#   'Number': 298},
#  {'_id': ObjectId('628d907528360e0bbf01e199'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '22',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'Spain',
#   'Number': 91},
#  {'_id': ObjectId('628d907528360e0bbf01e19a'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '23',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'Spain',
#   'Number': 541},
#  {'_id': ObjectId('628d907528360e0bbf01e19b'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '24',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'Spain',
#   'Number': 363},
#  {'_id': ObjectId('628d907528360e0bbf01e19c'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '25',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'Spain',
#   'Number': 587},
#  {'_id': ObjectId('628d907528360e0bbf01e19d'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '26',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'Spain',
#   'Number': 1146},
#  {'_id': ObjectId('628d907528360e0bbf01e19e'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '27',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'Spain',
#   'Number': 697},
#  {'_id': ObjectId('628d907528360e0bbf01e19f'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '28',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'Spain',
#   'Number': 347},
#  {'_id': ObjectId('628d907528360e0bbf01e1a0'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '29',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'Spain',
#   'Number': 171},
#  {'_id': ObjectId('628d907528360e0bbf01e1a1'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '30',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'Spain',
#   'Number': 283},
#  {'_id': ObjectId('628d907528360e0bbf01e1a2'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '31',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'Spain',
#   'Number': 1415},
#  {'_id': ObjectId('628d907528360e0bbf01e1a3'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '32',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'Spain',
#   'Number': 728},
#  {'_id': ObjectId('628d907528360e0bbf01e1a4'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '33',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'Spain',
#   'Number': 526},
#  {'_id': ObjectId('628d907528360e0bbf01e1a5'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '34',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'Spain',
#   'Number': 228},
#  {'_id': ObjectId('628d907528360e0bbf01e1a6'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '35',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'Spain',
#   'Number': 782},
#  {'_id': ObjectId('628d907528360e0bbf01e1a7'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '36',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'Spain',
#   'Number': 157},
#  {'_id': ObjectId('628d907528360e0bbf01e1a8'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '37',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'Spain',
#   'Number': 524},
#  {'_id': ObjectId('628d907528360e0bbf01e1a9'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '38',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'Spain',
#   'Number': 203},
#  {'_id': ObjectId('628d907528360e0bbf01e1aa'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '39',
#   'Neighborhood Name': 'Sant Genís dels Agudells',
#   'Nationality': 'Spain',
#   'Number': 152},
#  {'_id': ObjectId('628d907528360e0bbf01e1ab'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '40',
#   'Neighborhood Name': 'Montbau',
#   'Nationality': 'Spain',
#   'Number': 118},
#  {'_id': ObjectId('628d907528360e0bbf01e1ac'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '41',
#   'Neighborhood Name': "la Vall d'Hebron",
#   'Nationality': 'Spain',
#   'Number': 86},
#  {'_id': ObjectId('628d907528360e0bbf01e1ad'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '42',
#   'Neighborhood Name': 'la Clota',
#   'Nationality': 'Spain',
#   'Number': 16},
#  {'_id': ObjectId('628d907528360e0bbf01e1ae'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '43',
#   'Neighborhood Name': 'Horta',
#   'Nationality': 'Spain',
#   'Number': 463},
#  {'_id': ObjectId('628d907528360e0bbf01e1af'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '44',
#   'Neighborhood Name': 'Vilapicina i la Torre Llobeta',
#   'Nationality': 'Spain',
#   'Number': 431},
#  {'_id': ObjectId('628d907528360e0bbf01e1b0'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '45',
#   'Neighborhood Name': 'Porta',
#   'Nationality': 'Spain',
#   'Number': 501},
#  {'_id': ObjectId('628d907528360e0bbf01e1b1'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '46',
#   'Neighborhood Name': 'el Turó de la Peira',
#   'Nationality': 'Spain',
#   'Number': 314},
#  {'_id': ObjectId('628d907528360e0bbf01e1b2'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '47',
#   'Neighborhood Name': 'Can Peguera',
#   'Nationality': 'Spain',
#   'Number': 33},
#  {'_id': ObjectId('628d907528360e0bbf01e1b3'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '48',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'Spain',
#   'Number': 265},
#  {'_id': ObjectId('628d907528360e0bbf01e1b4'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '49',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'Spain',
#   'Number': 100},
#  {'_id': ObjectId('628d907528360e0bbf01e1b5'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '50',
#   'Neighborhood Name': 'les Roquetes',
#   'Nationality': 'Spain',
#   'Number': 287},
#  {'_id': ObjectId('628d907528360e0bbf01e1b6'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '51',
#   'Neighborhood Name': 'Verdun',
#   'Nationality': 'Spain',
#   'Number': 207},
#  {'_id': ObjectId('628d907528360e0bbf01e1b7'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '52',
#   'Neighborhood Name': 'la Prosperitat',
#   'Nationality': 'Spain',
#   'Number': 441},
#  {'_id': ObjectId('628d907528360e0bbf01e1b8'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '53',
#   'Neighborhood Name': 'la Trinitat Nova',
#   'Nationality': 'Spain',
#   'Number': 138},
#  {'_id': ObjectId('628d907528360e0bbf01e1b9'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '54',
#   'Neighborhood Name': 'Torre Baró',
#   'Nationality': 'Spain',
#   'Number': 36},
#  {'_id': ObjectId('628d907528360e0bbf01e1ba'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '55',
#   'Neighborhood Name': 'Ciutat Meridiana',
#   'Nationality': 'Spain',
#   'Number': 224},
#  {'_id': ObjectId('628d907528360e0bbf01e1bb'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '56',
#   'Neighborhood Name': 'Vallbona',
#   'Nationality': 'Spain',
#   'Number': 36},
#  {'_id': ObjectId('628d907528360e0bbf01e1bc'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '57',
#   'Neighborhood Name': 'la Trinitat Vella',
#   'Nationality': 'Spain',
#   'Number': 174},
#  {'_id': ObjectId('628d907528360e0bbf01e1bd'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '58',
#   'Neighborhood Name': 'Baró de Viver',
#   'Nationality': 'Spain',
#   'Number': 48},
#  {'_id': ObjectId('628d907528360e0bbf01e1be'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '59',
#   'Neighborhood Name': 'el Bon Pastor',
#   'Nationality': 'Spain',
#   'Number': 240},
#  {'_id': ObjectId('628d907528360e0bbf01e1bf'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '60',
#   'Neighborhood Name': 'Sant Andreu',
#   'Nationality': 'Spain',
#   'Number': 1042},
#  {'_id': ObjectId('628d907528360e0bbf01e1c0'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '61',
#   'Neighborhood Name': 'la Sagrera',
#   'Nationality': 'Spain',
#   'Number': 575},
#  {'_id': ObjectId('628d907528360e0bbf01e1c1'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '62',
#   'Neighborhood Name': 'el Congrés i els Indians',
#   'Nationality': 'Spain',
#   'Number': 243},
#  {'_id': ObjectId('628d907528360e0bbf01e1c2'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '63',
#   'Neighborhood Name': 'Navas',
#   'Nationality': 'Spain',
#   'Number': 391},
#  {'_id': ObjectId('628d907528360e0bbf01e1c3'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '64',
#   'Neighborhood Name': "el Camp de l'Arpa del Clot",
#   'Nationality': 'Spain',
#   'Number': 858},
#  {'_id': ObjectId('628d907528360e0bbf01e1c4'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '65',
#   'Neighborhood Name': 'el Clot',
#   'Nationality': 'Spain',
#   'Number': 510},
#  {'_id': ObjectId('628d907528360e0bbf01e1c5'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '66',
#   'Neighborhood Name': 'el Parc i la Llacuna del Poblenou',
#   'Nationality': 'Spain',
#   'Number': 302},
#  {'_id': ObjectId('628d907528360e0bbf01e1c6'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '67',
#   'Neighborhood Name': 'la Vila Olímpica del Poblenou',
#   'Nationality': 'Spain',
#   'Number': 178},
#  {'_id': ObjectId('628d907528360e0bbf01e1c7'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '68',
#   'Neighborhood Name': 'el Poblenou',
#   'Nationality': 'Spain',
#   'Number': 666},
#  {'_id': ObjectId('628d907528360e0bbf01e1c8'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '69',
#   'Neighborhood Name': 'Diagonal Mar i el Front Marítim del Poblenou',
#   'Nationality': 'Spain',
#   'Number': 257},
#  {'_id': ObjectId('628d907528360e0bbf01e1c9'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '70',
#   'Neighborhood Name': 'el Besòs i el Maresme',
#   'Nationality': 'Spain',
#   'Number': 538},
#  {'_id': ObjectId('628d907528360e0bbf01e1ca'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '71',
#   'Neighborhood Name': 'Provençals del Poblenou',
#   'Nationality': 'Spain',
#   'Number': 441},
#  {'_id': ObjectId('628d907528360e0bbf01e1cb'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '72',
#   'Neighborhood Name': 'Sant Martí de Provençals',
#   'Nationality': 'Spain',
#   'Number': 462},
#  {'_id': ObjectId('628d907528360e0bbf01e1cc'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '73',
#   'Neighborhood Name': 'la Verneda i la Pau',
#   'Nationality': 'Spain',
#   'Number': 514},
#  {'_id': ObjectId('628d907528360e0bbf01e1cd'),
#   'Year': '2017',
#   'District Code': '99',
#   'District Name': 'No consta',
#   'Neighborhood Code': '99',
#   'Neighborhood Name': 'No consta',
#   'Nationality': 'Spain',
#   'Number': 2},
#  {'_id': ObjectId('628d907528360e0bbf01e1ce'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '1',
#   'Neighborhood Name': 'el Raval',
#   'Nationality': 'Italy',
#   'Number': 360},
#  {'_id': ObjectId('628d907528360e0bbf01e1cf'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '2',
#   'Neighborhood Name': 'el Barri Gòtic',
#   'Nationality': 'Italy',
#   'Number': 275},
#  {'_id': ObjectId('628d907528360e0bbf01e1d0'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '3',
#   'Neighborhood Name': 'la Barceloneta',
#   'Nationality': 'Italy',
#   'Number': 285},
#  {'_id': ObjectId('628d907528360e0bbf01e1d1'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '4',
#   'Neighborhood Name': 'Sant Pere, Santa Caterina i la Ribera',
#   'Nationality': 'Italy',
#   'Number': 355},
#  {'_id': ObjectId('628d907528360e0bbf01e1d2'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '5',
#   'Neighborhood Name': 'el Fort Pienc',
#   'Nationality': 'Italy',
#   'Number': 207},
#  {'_id': ObjectId('628d907528360e0bbf01e1d3'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '6',
#   'Neighborhood Name': 'la Sagrada Família',
#   'Nationality': 'Italy',
#   'Number': 295},
#  {'_id': ObjectId('628d907528360e0bbf01e1d4'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '7',
#   'Neighborhood Name': "la Dreta de l'Eixample",
#   'Nationality': 'Italy',
#   'Number': 284},
#  {'_id': ObjectId('628d907528360e0bbf01e1d5'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '8',
#   'Neighborhood Name': "l'Antiga Esquerra de l'Eixample",
#   'Nationality': 'Italy',
#   'Number': 280},
#  {'_id': ObjectId('628d907528360e0bbf01e1d6'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '9',
#   'Neighborhood Name': "la Nova Esquerra de l'Eixample",
#   'Nationality': 'Italy',
#   'Number': 314},
#  {'_id': ObjectId('628d907528360e0bbf01e1d7'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '10',
#   'Neighborhood Name': 'Sant Antoni',
#   'Nationality': 'Italy',
#   'Number': 188},
#  {'_id': ObjectId('628d907528360e0bbf01e1d8'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '11',
#   'Neighborhood Name': 'el Poble Sec',
#   'Nationality': 'Italy',
#   'Number': 270},
#  {'_id': ObjectId('628d907528360e0bbf01e1d9'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '12',
#   'Neighborhood Name': 'la Marina del Prat Vermell',
#   'Nationality': 'Italy',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e1da'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '13',
#   'Neighborhood Name': 'la Marina de Port',
#   'Nationality': 'Italy',
#   'Number': 45},
#  {'_id': ObjectId('628d907528360e0bbf01e1db'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '14',
#   'Neighborhood Name': 'la Font de la Guatlla',
#   'Nationality': 'Italy',
#   'Number': 42},
#  {'_id': ObjectId('628d907528360e0bbf01e1dc'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '15',
#   'Neighborhood Name': 'Hostafrancs',
#   'Nationality': 'Italy',
#   'Number': 72},
#  {'_id': ObjectId('628d907528360e0bbf01e1dd'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '16',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'Italy',
#   'Number': 44},
#  {'_id': ObjectId('628d907528360e0bbf01e1de'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '17',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'Italy',
#   'Number': 56},
#  {'_id': ObjectId('628d907528360e0bbf01e1df'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '18',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'Italy',
#   'Number': 155},
#  {'_id': ObjectId('628d907528360e0bbf01e1e0'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '19',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'Italy',
#   'Number': 130},
#  {'_id': ObjectId('628d907528360e0bbf01e1e1'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '20',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'Italy',
#   'Number': 52},
#  {'_id': ObjectId('628d907528360e0bbf01e1e2'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '21',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'Italy',
#   'Number': 23},
#  {'_id': ObjectId('628d907528360e0bbf01e1e3'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '22',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'Italy',
#   'Number': 12},
#  {'_id': ObjectId('628d907528360e0bbf01e1e4'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '23',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'Italy',
#   'Number': 77},
#  {'_id': ObjectId('628d907528360e0bbf01e1e5'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '24',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'Italy',
#   'Number': 26},
#  {'_id': ObjectId('628d907528360e0bbf01e1e6'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '25',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'Italy',
#   'Number': 49},
#  {'_id': ObjectId('628d907528360e0bbf01e1e7'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '26',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'Italy',
#   'Number': 135},
#  {'_id': ObjectId('628d907528360e0bbf01e1e8'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '27',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'Italy',
#   'Number': 97},
#  {'_id': ObjectId('628d907528360e0bbf01e1e9'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '28',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'Italy',
#   'Number': 42},
#  {'_id': ObjectId('628d907528360e0bbf01e1ea'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '29',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'Italy',
#   'Number': 27},
#  {'_id': ObjectId('628d907528360e0bbf01e1eb'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '30',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'Italy',
#   'Number': 50},
#  {'_id': ObjectId('628d907528360e0bbf01e1ec'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '31',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'Italy',
#   'Number': 326},
#  {'_id': ObjectId('628d907528360e0bbf01e1ed'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '32',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'Italy',
#   'Number': 153},
#  {'_id': ObjectId('628d907528360e0bbf01e1ee'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '33',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'Italy',
#   'Number': 98},
#  {'_id': ObjectId('628d907528360e0bbf01e1ef'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '34',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'Italy',
#   'Number': 27},
#  {'_id': ObjectId('628d907528360e0bbf01e1f0'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '35',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'Italy',
#   'Number': 97},
#  {'_id': ObjectId('628d907528360e0bbf01e1f1'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '36',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'Italy',
#   'Number': 18},
#  {'_id': ObjectId('628d907528360e0bbf01e1f2'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '37',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'Italy',
#   'Number': 68},
#  {'_id': ObjectId('628d907528360e0bbf01e1f3'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '38',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'Italy',
#   'Number': 24},
#  {'_id': ObjectId('628d907528360e0bbf01e1f4'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '39',
#   'Neighborhood Name': 'Sant Genís dels Agudells',
#   'Nationality': 'Italy',
#   'Number': 8},
#  {'_id': ObjectId('628d907528360e0bbf01e1f5'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '40',
#   'Neighborhood Name': 'Montbau',
#   'Nationality': 'Italy',
#   'Number': 18},
#  {'_id': ObjectId('628d907528360e0bbf01e1f6'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '41',
#   'Neighborhood Name': "la Vall d'Hebron",
#   'Nationality': 'Italy',
#   'Number': 11},
#  {'_id': ObjectId('628d907528360e0bbf01e1f7'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '42',
#   'Neighborhood Name': 'la Clota',
#   'Nationality': 'Italy',
#   'Number': 3},
#  {'_id': ObjectId('628d907528360e0bbf01e1f8'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '43',
#   'Neighborhood Name': 'Horta',
#   'Nationality': 'Italy',
#   'Number': 41},
#  {'_id': ObjectId('628d907528360e0bbf01e1f9'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '44',
#   'Neighborhood Name': 'Vilapicina i la Torre Llobeta',
#   'Nationality': 'Italy',
#   'Number': 32},
#  {'_id': ObjectId('628d907528360e0bbf01e1fa'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '45',
#   'Neighborhood Name': 'Porta',
#   'Nationality': 'Italy',
#   'Number': 33},
#  {'_id': ObjectId('628d907528360e0bbf01e1fb'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '46',
#   'Neighborhood Name': 'el Turó de la Peira',
#   'Nationality': 'Italy',
#   'Number': 13},
#  {'_id': ObjectId('628d907528360e0bbf01e1fc'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '47',
#   'Neighborhood Name': 'Can Peguera',
#   'Nationality': 'Italy',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e1fd'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '48',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'Italy',
#   'Number': 4},
#  {'_id': ObjectId('628d907528360e0bbf01e1fe'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '49',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'Italy',
#   'Number': 1},
#  {'_id': ObjectId('628d907528360e0bbf01e1ff'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '50',
#   'Neighborhood Name': 'les Roquetes',
#   'Nationality': 'Italy',
#   'Number': 15},
#  {'_id': ObjectId('628d907528360e0bbf01e200'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '51',
#   'Neighborhood Name': 'Verdun',
#   'Nationality': 'Italy',
#   'Number': 12},
#  {'_id': ObjectId('628d907528360e0bbf01e201'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '52',
#   'Neighborhood Name': 'la Prosperitat',
#   'Nationality': 'Italy',
#   'Number': 16},
#  {'_id': ObjectId('628d907528360e0bbf01e202'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '53',
#   'Neighborhood Name': 'la Trinitat Nova',
#   'Nationality': 'Italy',
#   'Number': 12},
#  {'_id': ObjectId('628d907528360e0bbf01e203'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '54',
#   'Neighborhood Name': 'Torre Baró',
#   'Nationality': 'Italy',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e204'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '55',
#   'Neighborhood Name': 'Ciutat Meridiana',
#   'Nationality': 'Italy',
#   'Number': 7},
#  {'_id': ObjectId('628d907528360e0bbf01e205'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '56',
#   'Neighborhood Name': 'Vallbona',
#   'Nationality': 'Italy',
#   'Number': 1},
#  {'_id': ObjectId('628d907528360e0bbf01e206'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '57',
#   'Neighborhood Name': 'la Trinitat Vella',
#   'Nationality': 'Italy',
#   'Number': 10},
#  {'_id': ObjectId('628d907528360e0bbf01e207'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '58',
#   'Neighborhood Name': 'Baró de Viver',
#   'Nationality': 'Italy',
#   'Number': 2},
#  {'_id': ObjectId('628d907528360e0bbf01e208'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '59',
#   'Neighborhood Name': 'el Bon Pastor',
#   'Nationality': 'Italy',
#   'Number': 14},
#  {'_id': ObjectId('628d907528360e0bbf01e209'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '60',
#   'Neighborhood Name': 'Sant Andreu',
#   'Nationality': 'Italy',
#   'Number': 76},
#  {'_id': ObjectId('628d907528360e0bbf01e20a'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '61',
#   'Neighborhood Name': 'la Sagrera',
#   'Nationality': 'Italy',
#   'Number': 51},
#  {'_id': ObjectId('628d907528360e0bbf01e20b'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '62',
#   'Neighborhood Name': 'el Congrés i els Indians',
#   'Nationality': 'Italy',
#   'Number': 22},
#  {'_id': ObjectId('628d907528360e0bbf01e20c'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '63',
#   'Neighborhood Name': 'Navas',
#   'Nationality': 'Italy',
#   'Number': 51},
#  {'_id': ObjectId('628d907528360e0bbf01e20d'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '64',
#   'Neighborhood Name': "el Camp de l'Arpa del Clot",
#   'Nationality': 'Italy',
#   'Number': 181},
#  {'_id': ObjectId('628d907528360e0bbf01e20e'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '65',
#   'Neighborhood Name': 'el Clot',
#   'Nationality': 'Italy',
#   'Number': 93},
#  {'_id': ObjectId('628d907528360e0bbf01e20f'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '66',
#   'Neighborhood Name': 'el Parc i la Llacuna del Poblenou',
#   'Nationality': 'Italy',
#   'Number': 87},
#  {'_id': ObjectId('628d907528360e0bbf01e210'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '67',
#   'Neighborhood Name': 'la Vila Olímpica del Poblenou',
#   'Nationality': 'Italy',
#   'Number': 22},
#  {'_id': ObjectId('628d907528360e0bbf01e211'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '68',
#   'Neighborhood Name': 'el Poblenou',
#   'Nationality': 'Italy',
#   'Number': 156},
#  {'_id': ObjectId('628d907528360e0bbf01e212'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '69',
#   'Neighborhood Name': 'Diagonal Mar i el Front Marítim del Poblenou',
#   'Nationality': 'Italy',
#   'Number': 56},
#  {'_id': ObjectId('628d907528360e0bbf01e213'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '70',
#   'Neighborhood Name': 'el Besòs i el Maresme',
#   'Nationality': 'Italy',
#   'Number': 49},
#  {'_id': ObjectId('628d907528360e0bbf01e214'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '71',
#   'Neighborhood Name': 'Provençals del Poblenou',
#   'Nationality': 'Italy',
#   'Number': 47},
#  {'_id': ObjectId('628d907528360e0bbf01e215'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '72',
#   'Neighborhood Name': 'Sant Martí de Provençals',
#   'Nationality': 'Italy',
#   'Number': 50},
#  {'_id': ObjectId('628d907528360e0bbf01e216'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '73',
#   'Neighborhood Name': 'la Verneda i la Pau',
#   'Nationality': 'Italy',
#   'Number': 57},
#  {'_id': ObjectId('628d907528360e0bbf01e217'),
#   'Year': '2017',
#   'District Code': '99',
#   'District Name': 'No consta',
#   'Neighborhood Code': '99',
#   'Neighborhood Name': 'No consta',
#   'Nationality': 'Italy',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e218'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '1',
#   'Neighborhood Name': 'el Raval',
#   'Nationality': 'China',
#   'Number': 64},
#  {'_id': ObjectId('628d907528360e0bbf01e219'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '2',
#   'Neighborhood Name': 'el Barri Gòtic',
#   'Nationality': 'China',
#   'Number': 29},
#  {'_id': ObjectId('628d907528360e0bbf01e21a'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '3',
#   'Neighborhood Name': 'la Barceloneta',
#   'Nationality': 'China',
#   'Number': 8},
#  {'_id': ObjectId('628d907528360e0bbf01e21b'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '4',
#   'Neighborhood Name': 'Sant Pere, Santa Caterina i la Ribera',
#   'Nationality': 'China',
#   'Number': 33},
#  {'_id': ObjectId('628d907528360e0bbf01e21c'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '5',
#   'Neighborhood Name': 'el Fort Pienc',
#   'Nationality': 'China',
#   'Number': 195},
#  {'_id': ObjectId('628d907528360e0bbf01e21d'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '6',
#   'Neighborhood Name': 'la Sagrada Família',
#   'Nationality': 'China',
#   'Number': 210},
#  {'_id': ObjectId('628d907528360e0bbf01e21e'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '7',
#   'Neighborhood Name': "la Dreta de l'Eixample",
#   'Nationality': 'China',
#   'Number': 92},
#  {'_id': ObjectId('628d907528360e0bbf01e21f'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '8',
#   'Neighborhood Name': "l'Antiga Esquerra de l'Eixample",
#   'Nationality': 'China',
#   'Number': 105},
#  {'_id': ObjectId('628d907528360e0bbf01e220'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '9',
#   'Neighborhood Name': "la Nova Esquerra de l'Eixample",
#   'Nationality': 'China',
#   'Number': 200},
#  {'_id': ObjectId('628d907528360e0bbf01e221'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '10',
#   'Neighborhood Name': 'Sant Antoni',
#   'Nationality': 'China',
#   'Number': 116},
#  {'_id': ObjectId('628d907528360e0bbf01e222'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '11',
#   'Neighborhood Name': 'el Poble Sec',
#   'Nationality': 'China',
#   'Number': 75},
#  {'_id': ObjectId('628d907528360e0bbf01e223'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '12',
#   'Neighborhood Name': 'la Marina del Prat Vermell',
#   'Nationality': 'China',
#   'Number': 2},
#  {'_id': ObjectId('628d907528360e0bbf01e224'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '13',
#   'Neighborhood Name': 'la Marina de Port',
#   'Nationality': 'China',
#   'Number': 166},
#  {'_id': ObjectId('628d907528360e0bbf01e225'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '14',
#   'Neighborhood Name': 'la Font de la Guatlla',
#   'Nationality': 'China',
#   'Number': 23},
#  {'_id': ObjectId('628d907528360e0bbf01e226'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '15',
#   'Neighborhood Name': 'Hostafrancs',
#   'Nationality': 'China',
#   'Number': 47},
#  {'_id': ObjectId('628d907528360e0bbf01e227'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '16',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'China',
#   'Number': 25},
#  {'_id': ObjectId('628d907528360e0bbf01e228'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '17',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'China',
#   'Number': 75},
#  {'_id': ObjectId('628d907528360e0bbf01e229'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '18',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'China',
#   'Number': 99},
#  {'_id': ObjectId('628d907528360e0bbf01e22a'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '19',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'China',
#   'Number': 78},
#  {'_id': ObjectId('628d907528360e0bbf01e22b'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '20',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'China',
#   'Number': 40},
#  {'_id': ObjectId('628d907528360e0bbf01e22c'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '21',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'China',
#   'Number': 19},
#  {'_id': ObjectId('628d907528360e0bbf01e22d'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '22',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'China',
#   'Number': 1},
#  {'_id': ObjectId('628d907528360e0bbf01e22e'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '23',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'China',
#   'Number': 27},
#  {'_id': ObjectId('628d907528360e0bbf01e22f'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '24',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'China',
#   'Number': 7},
#  {'_id': ObjectId('628d907528360e0bbf01e230'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '25',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'China',
#   'Number': 53},
#  {'_id': ObjectId('628d907528360e0bbf01e231'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '26',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'China',
#   'Number': 45},
#  {'_id': ObjectId('628d907528360e0bbf01e232'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '27',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'China',
#   'Number': 30},
#  {'_id': ObjectId('628d907528360e0bbf01e233'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '28',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'China',
#   'Number': 13},
#  {'_id': ObjectId('628d907528360e0bbf01e234'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '29',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'China',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e235'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '30',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'China',
#   'Number': 18},
#  {'_id': ObjectId('628d907528360e0bbf01e236'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '31',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'China',
#   'Number': 74},
#  {'_id': ObjectId('628d907528360e0bbf01e237'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '32',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'China',
#   'Number': 35},
#  {'_id': ObjectId('628d907528360e0bbf01e238'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '33',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'China',
#   'Number': 44},
#  {'_id': ObjectId('628d907528360e0bbf01e239'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '34',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'China',
#   'Number': 8},
#  {'_id': ObjectId('628d907528360e0bbf01e23a'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '35',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'China',
#   'Number': 43},
#  {'_id': ObjectId('628d907528360e0bbf01e23b'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '36',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'China',
#   'Number': 2},
#  {'_id': ObjectId('628d907528360e0bbf01e23c'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '37',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'China',
#   'Number': 24},
#  {'_id': ObjectId('628d907528360e0bbf01e23d'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '38',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'China',
#   'Number': 6},
#  {'_id': ObjectId('628d907528360e0bbf01e23e'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '39',
#   'Neighborhood Name': 'Sant Genís dels Agudells',
#   'Nationality': 'China',
#   'Number': 9},
#  {'_id': ObjectId('628d907528360e0bbf01e23f'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '40',
#   'Neighborhood Name': 'Montbau',
#   'Nationality': 'China',
#   'Number': 4},
#  {'_id': ObjectId('628d907528360e0bbf01e240'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '41',
#   'Neighborhood Name': "la Vall d'Hebron",
#   'Nationality': 'China',
#   'Number': 4},
#  {'_id': ObjectId('628d907528360e0bbf01e241'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '42',
#   'Neighborhood Name': 'la Clota',
#   'Nationality': 'China',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e242'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '43',
#   'Neighborhood Name': 'Horta',
#   'Nationality': 'China',
#   'Number': 29},
#  {'_id': ObjectId('628d907528360e0bbf01e243'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '44',
#   'Neighborhood Name': 'Vilapicina i la Torre Llobeta',
#   'Nationality': 'China',
#   'Number': 71},
#  {'_id': ObjectId('628d907528360e0bbf01e244'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '45',
#   'Neighborhood Name': 'Porta',
#   'Nationality': 'China',
#   'Number': 38},
#  {'_id': ObjectId('628d907528360e0bbf01e245'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '46',
#   'Neighborhood Name': 'el Turó de la Peira',
#   'Nationality': 'China',
#   'Number': 24},
#  {'_id': ObjectId('628d907528360e0bbf01e246'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '47',
#   'Neighborhood Name': 'Can Peguera',
#   'Nationality': 'China',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e247'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '48',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'China',
#   'Number': 9},
#  {'_id': ObjectId('628d907528360e0bbf01e248'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '49',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'China',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e249'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '50',
#   'Neighborhood Name': 'les Roquetes',
#   'Nationality': 'China',
#   'Number': 37},
#  {'_id': ObjectId('628d907528360e0bbf01e24a'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '51',
#   'Neighborhood Name': 'Verdun',
#   'Nationality': 'China',
#   'Number': 26},
#  {'_id': ObjectId('628d907528360e0bbf01e24b'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '52',
#   'Neighborhood Name': 'la Prosperitat',
#   'Nationality': 'China',
#   'Number': 37},
#  {'_id': ObjectId('628d907528360e0bbf01e24c'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '53',
# ...
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '48',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'_id': ObjectId('628d907528360e0bbf01e52c'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '49',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'_id': ObjectId('628d907528360e0bbf01e52d'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '50',
#   'Neighborhood Name': 'les Roquetes',
#   'Nationality': 'United States',
#   'Number': 3},
#  {'_id': ObjectId('628d907528360e0bbf01e52e'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '51',
#   'Neighborhood Name': 'Verdun',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'_id': ObjectId('628d907528360e0bbf01e52f'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '52',
#   'Neighborhood Name': 'la Prosperitat',
#   'Nationality': 'United States',
#   'Number': 9},
#  {'_id': ObjectId('628d907528360e0bbf01e530'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '53',
#   'Neighborhood Name': 'la Trinitat Nova',
#   'Nationality': 'United States',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e531'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '54',
#   'Neighborhood Name': 'Torre Baró',
#   'Nationality': 'United States',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e532'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '55',
#   'Neighborhood Name': 'Ciutat Meridiana',
#   'Nationality': 'United States',
#   'Number': 6},
#  {'_id': ObjectId('628d907528360e0bbf01e533'),
#   'Year': '2017',
#   'District Code': '8',
#   'District Name': 'Nou Barris',
#   'Neighborhood Code': '56',
#   'Neighborhood Name': 'Vallbona',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'_id': ObjectId('628d907528360e0bbf01e534'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '57',
#   'Neighborhood Name': 'la Trinitat Vella',
#   'Nationality': 'United States',
#   'Number': 2},
#  {'_id': ObjectId('628d907528360e0bbf01e535'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '58',
#   'Neighborhood Name': 'Baró de Viver',
#   'Nationality': 'United States',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e536'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '59',
#   'Neighborhood Name': 'el Bon Pastor',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'_id': ObjectId('628d907528360e0bbf01e537'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '60',
#   'Neighborhood Name': 'Sant Andreu',
#   'Nationality': 'United States',
#   'Number': 13},
#  {'_id': ObjectId('628d907528360e0bbf01e538'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '61',
#   'Neighborhood Name': 'la Sagrera',
#   'Nationality': 'United States',
#   'Number': 7},
#  {'_id': ObjectId('628d907528360e0bbf01e539'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '62',
#   'Neighborhood Name': 'el Congrés i els Indians',
#   'Nationality': 'United States',
#   'Number': 3},
#  {'_id': ObjectId('628d907528360e0bbf01e53a'),
#   'Year': '2017',
#   'District Code': '9',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Code': '63',
#   'Neighborhood Name': 'Navas',
#   'Nationality': 'United States',
#   'Number': 6},
#  {'_id': ObjectId('628d907528360e0bbf01e53b'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '64',
#   'Neighborhood Name': "el Camp de l'Arpa del Clot",
#   'Nationality': 'United States',
#   'Number': 16},
#  {'_id': ObjectId('628d907528360e0bbf01e53c'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '65',
#   'Neighborhood Name': 'el Clot',
#   'Nationality': 'United States',
#   'Number': 17},
#  {'_id': ObjectId('628d907528360e0bbf01e53d'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '66',
#   'Neighborhood Name': 'el Parc i la Llacuna del Poblenou',
#   'Nationality': 'United States',
#   'Number': 17},
#  {'_id': ObjectId('628d907528360e0bbf01e53e'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '67',
#   'Neighborhood Name': 'la Vila Olímpica del Poblenou',
#   'Nationality': 'United States',
#   'Number': 12},
#  {'_id': ObjectId('628d907528360e0bbf01e53f'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '68',
#   'Neighborhood Name': 'el Poblenou',
#   'Nationality': 'United States',
#   'Number': 45},
#  {'_id': ObjectId('628d907528360e0bbf01e540'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '69',
#   'Neighborhood Name': 'Diagonal Mar i el Front Marítim del Poblenou',
#   'Nationality': 'United States',
#   'Number': 11},
#  {'_id': ObjectId('628d907528360e0bbf01e541'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '70',
#   'Neighborhood Name': 'el Besòs i el Maresme',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'_id': ObjectId('628d907528360e0bbf01e542'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '71',
#   'Neighborhood Name': 'Provençals del Poblenou',
#   'Nationality': 'United States',
#   'Number': 8},
#  {'_id': ObjectId('628d907528360e0bbf01e543'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '72',
#   'Neighborhood Name': 'Sant Martí de Provençals',
#   'Nationality': 'United States',
#   'Number': 5},
#  {'_id': ObjectId('628d907528360e0bbf01e544'),
#   'Year': '2017',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Neighborhood Code': '73',
#   'Neighborhood Name': 'la Verneda i la Pau',
#   'Nationality': 'United States',
#   'Number': 2},
#  {'_id': ObjectId('628d907528360e0bbf01e545'),
#   'Year': '2017',
#   'District Code': '99',
#   'District Name': 'No consta',
#   'Neighborhood Code': '99',
#   'Neighborhood Name': 'No consta',
#   'Nationality': 'United States',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e546'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '1',
#   'Neighborhood Name': 'el Raval',
#   'Nationality': 'United Kingdom',
#   'Number': 150},
#  {'_id': ObjectId('628d907528360e0bbf01e547'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '2',
#   'Neighborhood Name': 'el Barri Gòtic',
#   'Nationality': 'United Kingdom',
#   'Number': 78},
#  {'_id': ObjectId('628d907528360e0bbf01e548'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '3',
#   'Neighborhood Name': 'la Barceloneta',
#   'Nationality': 'United Kingdom',
#   'Number': 47},
#  {'_id': ObjectId('628d907528360e0bbf01e549'),
#   'Year': '2017',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Code': '4',
#   'Neighborhood Name': 'Sant Pere, Santa Caterina i la Ribera',
#   'Nationality': 'United Kingdom',
#   'Number': 118},
#  {'_id': ObjectId('628d907528360e0bbf01e54a'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '5',
#   'Neighborhood Name': 'el Fort Pienc',
#   'Nationality': 'United Kingdom',
#   'Number': 39},
#  {'_id': ObjectId('628d907528360e0bbf01e54b'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '6',
#   'Neighborhood Name': 'la Sagrada Família',
#   'Nationality': 'United Kingdom',
#   'Number': 37},
#  {'_id': ObjectId('628d907528360e0bbf01e54c'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '7',
#   'Neighborhood Name': "la Dreta de l'Eixample",
#   'Nationality': 'United Kingdom',
#   'Number': 82},
#  {'_id': ObjectId('628d907528360e0bbf01e54d'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '8',
#   'Neighborhood Name': "l'Antiga Esquerra de l'Eixample",
#   'Nationality': 'United Kingdom',
#   'Number': 59},
#  {'_id': ObjectId('628d907528360e0bbf01e54e'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '9',
#   'Neighborhood Name': "la Nova Esquerra de l'Eixample",
#   'Nationality': 'United Kingdom',
#   'Number': 57},
#  {'_id': ObjectId('628d907528360e0bbf01e54f'),
#   'Year': '2017',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Neighborhood Code': '10',
#   'Neighborhood Name': 'Sant Antoni',
#   'Nationality': 'United Kingdom',
#   'Number': 52},
#  {'_id': ObjectId('628d907528360e0bbf01e550'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '11',
#   'Neighborhood Name': 'el Poble Sec',
#   'Nationality': 'United Kingdom',
#   'Number': 71},
#  {'_id': ObjectId('628d907528360e0bbf01e551'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '12',
#   'Neighborhood Name': 'la Marina del Prat Vermell',
#   'Nationality': 'United Kingdom',
#   'Number': 0},
#  {'_id': ObjectId('628d907528360e0bbf01e552'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '13',
#   'Neighborhood Name': 'la Marina de Port',
#   'Nationality': 'United Kingdom',
#   'Number': 2},
#  {'_id': ObjectId('628d907528360e0bbf01e553'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '14',
#   'Neighborhood Name': 'la Font de la Guatlla',
#   'Nationality': 'United Kingdom',
#   'Number': 9},
#  {'_id': ObjectId('628d907528360e0bbf01e554'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '15',
#   'Neighborhood Name': 'Hostafrancs',
#   'Nationality': 'United Kingdom',
#   'Number': 8},
#  {'_id': ObjectId('628d907528360e0bbf01e555'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '16',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'United Kingdom',
#   'Number': 10},
#  {'_id': ObjectId('628d907528360e0bbf01e556'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '17',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'United Kingdom',
#   'Number': 9},
#  {'_id': ObjectId('628d907528360e0bbf01e557'),
#   'Year': '2017',
#   'District Code': '3',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Code': '18',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'United Kingdom',
#   'Number': 22},
#  {'_id': ObjectId('628d907528360e0bbf01e558'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '19',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'United Kingdom',
#   'Number': 19},
#  {'_id': ObjectId('628d907528360e0bbf01e559'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '20',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'United Kingdom',
#   'Number': 13},
#  {'_id': ObjectId('628d907528360e0bbf01e55a'),
#   'Year': '2017',
#   'District Code': '4',
#   'District Name': 'Les Corts',
#   'Neighborhood Code': '21',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'United Kingdom',
#   'Number': 13},
#  {'_id': ObjectId('628d907528360e0bbf01e55b'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '22',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'United Kingdom',
#   'Number': 3},
#  {'_id': ObjectId('628d907528360e0bbf01e55c'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '23',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'United Kingdom',
#   'Number': 26},
#  {'_id': ObjectId('628d907528360e0bbf01e55d'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '24',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'United Kingdom',
#   'Number': 18},
#  {'_id': ObjectId('628d907528360e0bbf01e55e'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '25',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'United Kingdom',
#   'Number': 19},
#  {'_id': ObjectId('628d907528360e0bbf01e55f'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '26',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'United Kingdom',
#   'Number': 42},
#  {'_id': ObjectId('628d907528360e0bbf01e560'),
#   'Year': '2017',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Code': '27',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'United Kingdom',
#   'Number': 18},
#  {'_id': ObjectId('628d907528360e0bbf01e561'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '28',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'United Kingdom',
#   'Number': 11},
#  {'_id': ObjectId('628d907528360e0bbf01e562'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '29',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'United Kingdom',
#   'Number': 1},
#  {'_id': ObjectId('628d907528360e0bbf01e563'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '30',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'United Kingdom',
#   'Number': 15},
#  {'_id': ObjectId('628d907528360e0bbf01e564'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '31',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'United Kingdom',
#   'Number': 94},
#  {'_id': ObjectId('628d907528360e0bbf01e565'),
#   'Year': '2017',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Neighborhood Code': '32',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'United Kingdom',
#   'Number': 30},
#  {'_id': ObjectId('628d907528360e0bbf01e566'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '33',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'United Kingdom',
#   'Number': 14},
#  {'_id': ObjectId('628d907528360e0bbf01e567'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '34',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'United Kingdom',
#   'Number': 5},
#  {'_id': ObjectId('628d907528360e0bbf01e568'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '35',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'United Kingdom',
#   'Number': 11},
#  {'_id': ObjectId('628d907528360e0bbf01e569'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '36',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'United Kingdom',
#   'Number': 2},
#  {'_id': ObjectId('628d907528360e0bbf01e56a'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '37',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'United Kingdom',
#   'Number': 4},
#  {'_id': ObjectId('628d907528360e0bbf01e56b'),
#   'Year': '2017',
#   'District Code': '7',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Code': '38',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'United Kingdom',
#   'Number': 5},
#  ...]

# %%
inm_nat= db["Nacionalidades"]

# %%
inm_nat_clean = data_inm_nat.to_dict('records')

# %%
inm_nat_clean
# Out:
# [{'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Raval',
#   'Nationality': 'Spain',
#   'Number': 1109},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Barri Gòtic',
#   'Nationality': 'Spain',
#   'Number': 482},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'la Barceloneta',
#   'Nationality': 'Spain',
#   'Number': 414},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'Sant Pere, Santa Caterina i la Ribera',
#   'Nationality': 'Spain',
#   'Number': 537},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'el Fort Pienc',
#   'Nationality': 'Spain',
#   'Number': 663},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'la Sagrada Família',
#   'Nationality': 'Spain',
#   'Number': 1181},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Dreta de l'Eixample",
#   'Nationality': 'Spain',
#   'Number': 1063},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "l'Antiga Esquerra de l'Eixample",
#   'Nationality': 'Spain',
#   'Number': 1177},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Nova Esquerra de l'Eixample",
#   'Nationality': 'Spain',
#   'Number': 1593},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'Sant Antoni',
#   'Nationality': 'Spain',
#   'Number': 883},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'el Poble Sec',
#   'Nationality': 'Spain',
#   'Number': 826},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina del Prat Vermell',
#   'Nationality': 'Spain',
#   'Number': 23},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina de Port',
#   'Nationality': 'Spain',
#   'Number': 574},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Font de la Guatlla',
#   'Nationality': 'Spain',
#   'Number': 264},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Hostafrancs',
#   'Nationality': 'Spain',
#   'Number': 410},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'Spain',
#   'Number': 434},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'Spain',
#   'Number': 605},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'Spain',
#   'Number': 1083},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'Spain',
#   'Number': 1027},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'Spain',
#   'Number': 630},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'Spain',
#   'Number': 298},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'Spain',
#   'Number': 91},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'Spain',
#   'Number': 541},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'Spain',
#   'Number': 363},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'Spain',
#   'Number': 587},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'Spain',
#   'Number': 1146},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'Spain',
#   'Number': 697},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'Spain',
#   'Number': 347},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'Spain',
#   'Number': 171},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'Spain',
#   'Number': 283},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'Spain',
#   'Number': 1415},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'Spain',
#   'Number': 728},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'Spain',
#   'Number': 526},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'Spain',
#   'Number': 228},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'Spain',
#   'Number': 782},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'Spain',
#   'Number': 157},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'Spain',
#   'Number': 524},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'Spain',
#   'Number': 203},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Sant Genís dels Agudells',
#   'Nationality': 'Spain',
#   'Number': 152},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Montbau',
#   'Nationality': 'Spain',
#   'Number': 118},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Vall d'Hebron",
#   'Nationality': 'Spain',
#   'Number': 86},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Clota',
#   'Nationality': 'Spain',
#   'Number': 16},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Horta',
#   'Nationality': 'Spain',
#   'Number': 463},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vilapicina i la Torre Llobeta',
#   'Nationality': 'Spain',
#   'Number': 431},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Porta',
#   'Nationality': 'Spain',
#   'Number': 501},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'el Turó de la Peira',
#   'Nationality': 'Spain',
#   'Number': 314},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Can Peguera',
#   'Nationality': 'Spain',
#   'Number': 33},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'Spain',
#   'Number': 265},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'Spain',
#   'Number': 100},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'les Roquetes',
#   'Nationality': 'Spain',
#   'Number': 287},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Verdun',
#   'Nationality': 'Spain',
#   'Number': 207},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Prosperitat',
#   'Nationality': 'Spain',
#   'Number': 441},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Trinitat Nova',
#   'Nationality': 'Spain',
#   'Number': 138},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Torre Baró',
#   'Nationality': 'Spain',
#   'Number': 36},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Ciutat Meridiana',
#   'Nationality': 'Spain',
#   'Number': 224},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vallbona',
#   'Nationality': 'Spain',
#   'Number': 36},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'la Trinitat Vella',
#   'Nationality': 'Spain',
#   'Number': 174},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Baró de Viver',
#   'Nationality': 'Spain',
#   'Number': 48},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'el Bon Pastor',
#   'Nationality': 'Spain',
#   'Number': 240},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Sant Andreu',
#   'Nationality': 'Spain',
#   'Number': 1042},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'la Sagrera',
#   'Nationality': 'Spain',
#   'Number': 575},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'el Congrés i els Indians',
#   'Nationality': 'Spain',
#   'Number': 243},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Navas',
#   'Nationality': 'Spain',
#   'Number': 391},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': "el Camp de l'Arpa del Clot",
#   'Nationality': 'Spain',
#   'Number': 858},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Clot',
#   'Nationality': 'Spain',
#   'Number': 510},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Parc i la Llacuna del Poblenou',
#   'Nationality': 'Spain',
#   'Number': 302},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'la Vila Olímpica del Poblenou',
#   'Nationality': 'Spain',
#   'Number': 178},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Poblenou',
#   'Nationality': 'Spain',
#   'Number': 666},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Diagonal Mar i el Front Marítim del Poblenou',
#   'Nationality': 'Spain',
#   'Number': 257},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Besòs i el Maresme',
#   'Nationality': 'Spain',
#   'Number': 538},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Provençals del Poblenou',
#   'Nationality': 'Spain',
#   'Number': 441},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Sant Martí de Provençals',
#   'Nationality': 'Spain',
#   'Number': 462},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'la Verneda i la Pau',
#   'Nationality': 'Spain',
#   'Number': 514},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Raval',
#   'Nationality': 'Italy',
#   'Number': 360},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Barri Gòtic',
#   'Nationality': 'Italy',
#   'Number': 275},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'la Barceloneta',
#   'Nationality': 'Italy',
#   'Number': 285},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'Sant Pere, Santa Caterina i la Ribera',
#   'Nationality': 'Italy',
#   'Number': 355},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'el Fort Pienc',
#   'Nationality': 'Italy',
#   'Number': 207},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'la Sagrada Família',
#   'Nationality': 'Italy',
#   'Number': 295},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Dreta de l'Eixample",
#   'Nationality': 'Italy',
#   'Number': 284},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "l'Antiga Esquerra de l'Eixample",
#   'Nationality': 'Italy',
#   'Number': 280},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Nova Esquerra de l'Eixample",
#   'Nationality': 'Italy',
#   'Number': 314},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'Sant Antoni',
#   'Nationality': 'Italy',
#   'Number': 188},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'el Poble Sec',
#   'Nationality': 'Italy',
#   'Number': 270},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina del Prat Vermell',
#   'Nationality': 'Italy',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina de Port',
#   'Nationality': 'Italy',
#   'Number': 45},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Font de la Guatlla',
#   'Nationality': 'Italy',
#   'Number': 42},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Hostafrancs',
#   'Nationality': 'Italy',
#   'Number': 72},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'Italy',
#   'Number': 44},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'Italy',
#   'Number': 56},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'Italy',
#   'Number': 155},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'Italy',
#   'Number': 130},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'Italy',
#   'Number': 52},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'Italy',
#   'Number': 23},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'Italy',
#   'Number': 12},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'Italy',
#   'Number': 77},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'Italy',
#   'Number': 26},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'Italy',
#   'Number': 49},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'Italy',
#   'Number': 135},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'Italy',
#   'Number': 97},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'Italy',
#   'Number': 42},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'Italy',
#   'Number': 27},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'Italy',
#   'Number': 50},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'Italy',
#   'Number': 326},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'Italy',
#   'Number': 153},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'Italy',
#   'Number': 98},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'Italy',
#   'Number': 27},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'Italy',
#   'Number': 97},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'Italy',
#   'Number': 18},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'Italy',
#   'Number': 68},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'Italy',
#   'Number': 24},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Sant Genís dels Agudells',
#   'Nationality': 'Italy',
#   'Number': 8},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Montbau',
#   'Nationality': 'Italy',
#   'Number': 18},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Vall d'Hebron",
#   'Nationality': 'Italy',
#   'Number': 11},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Clota',
#   'Nationality': 'Italy',
#   'Number': 3},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Horta',
#   'Nationality': 'Italy',
#   'Number': 41},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vilapicina i la Torre Llobeta',
#   'Nationality': 'Italy',
#   'Number': 32},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Porta',
#   'Nationality': 'Italy',
#   'Number': 33},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'el Turó de la Peira',
#   'Nationality': 'Italy',
#   'Number': 13},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Can Peguera',
#   'Nationality': 'Italy',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'Italy',
#   'Number': 4},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'Italy',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'les Roquetes',
#   'Nationality': 'Italy',
#   'Number': 15},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Verdun',
#   'Nationality': 'Italy',
#   'Number': 12},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Prosperitat',
#   'Nationality': 'Italy',
#   'Number': 16},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Trinitat Nova',
#   'Nationality': 'Italy',
#   'Number': 12},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Torre Baró',
#   'Nationality': 'Italy',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Ciutat Meridiana',
#   'Nationality': 'Italy',
#   'Number': 7},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vallbona',
#   'Nationality': 'Italy',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'la Trinitat Vella',
#   'Nationality': 'Italy',
#   'Number': 10},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Baró de Viver',
#   'Nationality': 'Italy',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'el Bon Pastor',
#   'Nationality': 'Italy',
#   'Number': 14},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Sant Andreu',
#   'Nationality': 'Italy',
#   'Number': 76},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'la Sagrera',
#   'Nationality': 'Italy',
#   'Number': 51},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'el Congrés i els Indians',
#   'Nationality': 'Italy',
#   'Number': 22},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Navas',
#   'Nationality': 'Italy',
#   'Number': 51},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': "el Camp de l'Arpa del Clot",
#   'Nationality': 'Italy',
#   'Number': 181},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Clot',
#   'Nationality': 'Italy',
#   'Number': 93},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Parc i la Llacuna del Poblenou',
#   'Nationality': 'Italy',
#   'Number': 87},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'la Vila Olímpica del Poblenou',
#   'Nationality': 'Italy',
#   'Number': 22},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Poblenou',
#   'Nationality': 'Italy',
#   'Number': 156},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Diagonal Mar i el Front Marítim del Poblenou',
#   'Nationality': 'Italy',
#   'Number': 56},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Besòs i el Maresme',
#   'Nationality': 'Italy',
#   'Number': 49},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Provençals del Poblenou',
#   'Nationality': 'Italy',
#   'Number': 47},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Sant Martí de Provençals',
#   'Nationality': 'Italy',
#   'Number': 50},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'la Verneda i la Pau',
#   'Nationality': 'Italy',
#   'Number': 57},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Raval',
#   'Nationality': 'China',
#   'Number': 64},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Barri Gòtic',
#   'Nationality': 'China',
#   'Number': 29},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'la Barceloneta',
#   'Nationality': 'China',
#   'Number': 8},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'Sant Pere, Santa Caterina i la Ribera',
#   'Nationality': 'China',
#   'Number': 33},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'el Fort Pienc',
#   'Nationality': 'China',
#   'Number': 195},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'la Sagrada Família',
#   'Nationality': 'China',
#   'Number': 210},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Dreta de l'Eixample",
#   'Nationality': 'China',
#   'Number': 92},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "l'Antiga Esquerra de l'Eixample",
#   'Nationality': 'China',
#   'Number': 105},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Nova Esquerra de l'Eixample",
#   'Nationality': 'China',
#   'Number': 200},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'Sant Antoni',
#   'Nationality': 'China',
#   'Number': 116},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'el Poble Sec',
#   'Nationality': 'China',
#   'Number': 75},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina del Prat Vermell',
#   'Nationality': 'China',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina de Port',
#   'Nationality': 'China',
#   'Number': 166},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Font de la Guatlla',
#   'Nationality': 'China',
#   'Number': 23},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Hostafrancs',
#   'Nationality': 'China',
#   'Number': 47},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'China',
#   'Number': 25},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'China',
#   'Number': 75},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'China',
#   'Number': 99},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'China',
#   'Number': 78},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'China',
#   'Number': 40},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'China',
#   'Number': 19},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'China',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'China',
#   'Number': 27},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'China',
#   'Number': 7},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'China',
#   'Number': 53},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'China',
#   'Number': 45},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'China',
#   'Number': 30},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'China',
#   'Number': 13},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'China',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'China',
#   'Number': 18},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'China',
#   'Number': 74},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'China',
#   'Number': 35},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'China',
#   'Number': 44},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'China',
#   'Number': 8},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'China',
#   'Number': 43},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'China',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'China',
#   'Number': 24},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'China',
#   'Number': 6},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Sant Genís dels Agudells',
#   'Nationality': 'China',
#   'Number': 9},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Montbau',
#   'Nationality': 'China',
#   'Number': 4},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Vall d'Hebron",
#   'Nationality': 'China',
#   'Number': 4},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Clota',
#   'Nationality': 'China',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Horta',
#   'Nationality': 'China',
#   'Number': 29},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vilapicina i la Torre Llobeta',
#   'Nationality': 'China',
#   'Number': 71},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Porta',
#   'Nationality': 'China',
#   'Number': 38},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'el Turó de la Peira',
#   'Nationality': 'China',
#   'Number': 24},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Can Peguera',
#   'Nationality': 'China',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'China',
#   'Number': 9},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'China',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'les Roquetes',
#   'Nationality': 'China',
#   'Number': 37},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Verdun',
#   'Nationality': 'China',
#   'Number': 26},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Prosperitat',
#   'Nationality': 'China',
#   'Number': 37},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Trinitat Nova',
#   'Nationality': 'China',
#   'Number': 3},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Torre Baró',
#   'Nationality': 'China',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Ciutat Meridiana',
#   'Nationality': 'China',
#   'Number': 19},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vallbona',
#   'Nationality': 'China',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'la Trinitat Vella',
#   'Nationality': 'China',
#   'Number': 10},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Baró de Viver',
#   'Nationality': 'China',
#   'Number': 3},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'el Bon Pastor',
#   'Nationality': 'China',
#   'Number': 15},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Sant Andreu',
#   'Nationality': 'China',
#   'Number': 67},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'la Sagrera',
#   'Nationality': 'China',
#   'Number': 75},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'el Congrés i els Indians',
#   'Nationality': 'China',
#   'Number': 27},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Navas',
#   'Nationality': 'China',
#   'Number': 53},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': "el Camp de l'Arpa del Clot",
#   'Nationality': 'China',
#   'Number': 121},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Clot',
#   'Nationality': 'China',
#   'Number': 78},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Parc i la Llacuna del Poblenou',
#   'Nationality': 'China',
#   'Number': 52},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'la Vila Olímpica del Poblenou',
#   'Nationality': 'China',
#   'Number': 5},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Poblenou',
#   'Nationality': 'China',
#   'Number': 27},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Diagonal Mar i el Front Marítim del Poblenou',
#   'Nationality': 'China',
#   'Number': 29},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Besòs i el Maresme',
#   'Nationality': 'China',
#   'Number': 59},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Provençals del Poblenou',
#   'Nationality': 'China',
#   'Number': 27},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Sant Martí de Provençals',
#   'Nationality': 'China',
#   'Number': 110},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'la Verneda i la Pau',
#   'Nationality': 'China',
#   'Number': 98},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Raval',
#   'Nationality': 'Colombia',
#   'Number': 104},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Barri Gòtic',
#   'Nationality': 'Colombia',
#   'Number': 53},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'la Barceloneta',
#   'Nationality': 'Colombia',
#   'Number': 48},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'Sant Pere, Santa Caterina i la Ribera',
#   'Nationality': 'Colombia',
#   'Number': 64},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'el Fort Pienc',
#   'Nationality': 'Colombia',
#   'Number': 82},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'la Sagrada Família',
#   'Nationality': 'Colombia',
#   'Number': 155},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Dreta de l'Eixample",
#   'Nationality': 'Colombia',
#   'Number': 101},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "l'Antiga Esquerra de l'Eixample",
#   'Nationality': 'Colombia',
#   'Number': 163},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Nova Esquerra de l'Eixample",
#   'Nationality': 'Colombia',
#   'Number': 174},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'Sant Antoni',
#   'Nationality': 'Colombia',
#   'Number': 106},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'el Poble Sec',
#   'Nationality': 'Colombia',
#   'Number': 95},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina del Prat Vermell',
#   'Nationality': 'Colombia',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina de Port',
#   'Nationality': 'Colombia',
#   'Number': 80},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Font de la Guatlla',
#   'Nationality': 'Colombia',
#   'Number': 25},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Hostafrancs',
#   'Nationality': 'Colombia',
#   'Number': 44},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'Colombia',
#   'Number': 32},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'Colombia',
#   'Number': 59},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'Colombia',
#   'Number': 95},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'Colombia',
#   'Number': 65},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'Colombia',
#   'Number': 50},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'Colombia',
#   'Number': 18},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'Colombia',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'Colombia',
#   'Number': 20},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'Colombia',
#   'Number': 10},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'Colombia',
#   'Number': 12},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'Colombia',
#   'Number': 48},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'Colombia',
#   'Number': 38},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'Colombia',
#   'Number': 20},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'Colombia',
#   'Number': 14},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'Colombia',
#   'Number': 13},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'Colombia',
#   'Number': 99},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'Colombia',
#   'Number': 54},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'Colombia',
#   'Number': 48},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'Colombia',
#   'Number': 18},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'Colombia',
#   'Number': 88},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'Colombia',
#   'Number': 7},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'Colombia',
#   'Number': 65},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'Colombia',
#   'Number': 10},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Sant Genís dels Agudells',
#   'Nationality': 'Colombia',
#   'Number': 10},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Montbau',
#   'Nationality': 'Colombia',
#   'Number': 11},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Vall d'Hebron",
#   'Nationality': 'Colombia',
#   'Number': 12},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Clota',
#   'Nationality': 'Colombia',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Horta',
#   'Nationality': 'Colombia',
#   'Number': 49},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vilapicina i la Torre Llobeta',
#   'Nationality': 'Colombia',
#   'Number': 61},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Porta',
#   'Nationality': 'Colombia',
#   'Number': 78},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'el Turó de la Peira',
#   'Nationality': 'Colombia',
#   'Number': 48},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Can Peguera',
#   'Nationality': 'Colombia',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'Colombia',
#   'Number': 23},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'Colombia',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'les Roquetes',
#   'Nationality': 'Colombia',
#   'Number': 22},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Verdun',
#   'Nationality': 'Colombia',
#   'Number': 21},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Prosperitat',
#   'Nationality': 'Colombia',
#   'Number': 45},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Trinitat Nova',
#   'Nationality': 'Colombia',
#   'Number': 21},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Torre Baró',
#   'Nationality': 'Colombia',
#   'Number': 3},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Ciutat Meridiana',
#   'Nationality': 'Colombia',
#   'Number': 22},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vallbona',
#   'Nationality': 'Colombia',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'la Trinitat Vella',
#   'Nationality': 'Colombia',
#   'Number': 30},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Baró de Viver',
#   'Nationality': 'Colombia',
#   'Number': 6},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'el Bon Pastor',
#   'Nationality': 'Colombia',
#   'Number': 31},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Sant Andreu',
#   'Nationality': 'Colombia',
#   'Number': 79},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'la Sagrera',
#   'Nationality': 'Colombia',
#   'Number': 63},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'el Congrés i els Indians',
#   'Nationality': 'Colombia',
#   'Number': 44},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Navas',
#   'Nationality': 'Colombia',
#   'Number': 17},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': "el Camp de l'Arpa del Clot",
#   'Nationality': 'Colombia',
#   'Number': 91},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Clot',
#   'Nationality': 'Colombia',
#   'Number': 64},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Parc i la Llacuna del Poblenou',
#   'Nationality': 'Colombia',
#   'Number': 17},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'la Vila Olímpica del Poblenou',
#   'Nationality': 'Colombia',
#   'Number': 4},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Poblenou',
#   'Nationality': 'Colombia',
#   'Number': 43},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Diagonal Mar i el Front Marítim del Poblenou',
#   'Nationality': 'Colombia',
#   'Number': 22},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Besòs i el Maresme',
#   'Nationality': 'Colombia',
#   'Number': 41},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Provençals del Poblenou',
#   'Nationality': 'Colombia',
#   'Number': 23},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Sant Martí de Provençals',
#   'Nationality': 'Colombia',
#   'Number': 38},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'la Verneda i la Pau',
#   'Nationality': 'Colombia',
#   'Number': 32},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Raval',
#   'Nationality': 'Venezuela',
#   'Number': 106},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Barri Gòtic',
#   'Nationality': 'Venezuela',
#   'Number': 52},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'la Barceloneta',
#   'Nationality': 'Venezuela',
#   'Number': 47},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'Sant Pere, Santa Caterina i la Ribera',
#   'Nationality': 'Venezuela',
#   'Number': 61},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'el Fort Pienc',
#   'Nationality': 'Venezuela',
#   'Number': 80},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'la Sagrada Família',
#   'Nationality': 'Venezuela',
#   'Number': 225},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Dreta de l'Eixample",
#   'Nationality': 'Venezuela',
#   'Number': 84},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "l'Antiga Esquerra de l'Eixample",
#   'Nationality': 'Venezuela',
#   'Number': 135},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Nova Esquerra de l'Eixample",
#   'Nationality': 'Venezuela',
#   'Number': 129},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'Sant Antoni',
#   'Nationality': 'Venezuela',
#   'Number': 71},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'el Poble Sec',
#   'Nationality': 'Venezuela',
#   'Number': 63},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina del Prat Vermell',
#   'Nationality': 'Venezuela',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina de Port',
#   'Nationality': 'Venezuela',
#   'Number': 42},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Font de la Guatlla',
#   'Nationality': 'Venezuela',
#   'Number': 28},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Hostafrancs',
#   'Nationality': 'Venezuela',
#   'Number': 27},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'Venezuela',
#   'Number': 37},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'Venezuela',
#   'Number': 51},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'Venezuela',
#   'Number': 85},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'Venezuela',
#   'Number': 94},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'Venezuela',
#   'Number': 67},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'Venezuela',
#   'Number': 17},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'Venezuela',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'Venezuela',
#   'Number': 30},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'Venezuela',
#   'Number': 6},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'Venezuela',
#   'Number': 35},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'Venezuela',
#   'Number': 69},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'Venezuela',
#   'Number': 73},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'Venezuela',
#   'Number': 32},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'Venezuela',
#   'Number': 11},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'Venezuela',
#   'Number': 28},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'Venezuela',
#   'Number': 72},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'Venezuela',
#   'Number': 46},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'Venezuela',
#   'Number': 60},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'Venezuela',
#   'Number': 18},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'Venezuela',
#   'Number': 82},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'Venezuela',
#   'Number': 4},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'Venezuela',
#   'Number': 77},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'Venezuela',
#   'Number': 26},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Sant Genís dels Agudells',
#   'Nationality': 'Venezuela',
#   'Number': 22},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Montbau',
#   'Nationality': 'Venezuela',
#   'Number': 11},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Vall d'Hebron",
#   'Nationality': 'Venezuela',
#   'Number': 12},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Clota',
#   'Nationality': 'Venezuela',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Horta',
#   'Nationality': 'Venezuela',
#   'Number': 28},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vilapicina i la Torre Llobeta',
#   'Nationality': 'Venezuela',
#   'Number': 40},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Porta',
#   'Nationality': 'Venezuela',
#   'Number': 41},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'el Turó de la Peira',
#   'Nationality': 'Venezuela',
#   'Number': 15},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Can Peguera',
#   'Nationality': 'Venezuela',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'Venezuela',
#   'Number': 10},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'Venezuela',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'les Roquetes',
# ...
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'United States',
#   'Number': 5},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'United States',
#   'Number': 4},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'United States',
#   'Number': 47},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'United States',
#   'Number': 58},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'United States',
#   'Number': 11},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'United States',
#   'Number': 26},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'United States',
#   'Number': 4},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'United States',
#   'Number': 28},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'United States',
#   'Number': 59},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'United States',
#   'Number': 21},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'United States',
#   'Number': 121},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'United States',
#   'Number': 30},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'United States',
#   'Number': 10},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'United States',
#   'Number': 8},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'United States',
#   'Number': 96},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'United States',
#   'Number': 16},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'United States',
#   'Number': 11},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'United States',
#   'Number': 8},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'United States',
#   'Number': 6},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'United States',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'United States',
#   'Number': 6},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'United States',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Sant Genís dels Agudells',
#   'Nationality': 'United States',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Montbau',
#   'Nationality': 'United States',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Vall d'Hebron",
#   'Nationality': 'United States',
#   'Number': 3},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Clota',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Horta',
#   'Nationality': 'United States',
#   'Number': 8},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vilapicina i la Torre Llobeta',
#   'Nationality': 'United States',
#   'Number': 3},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Porta',
#   'Nationality': 'United States',
#   'Number': 8},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'el Turó de la Peira',
#   'Nationality': 'United States',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Can Peguera',
#   'Nationality': 'United States',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'les Roquetes',
#   'Nationality': 'United States',
#   'Number': 3},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Verdun',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Prosperitat',
#   'Nationality': 'United States',
#   'Number': 9},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Trinitat Nova',
#   'Nationality': 'United States',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Torre Baró',
#   'Nationality': 'United States',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Ciutat Meridiana',
#   'Nationality': 'United States',
#   'Number': 6},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vallbona',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'la Trinitat Vella',
#   'Nationality': 'United States',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Baró de Viver',
#   'Nationality': 'United States',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'el Bon Pastor',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Sant Andreu',
#   'Nationality': 'United States',
#   'Number': 13},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'la Sagrera',
#   'Nationality': 'United States',
#   'Number': 7},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'el Congrés i els Indians',
#   'Nationality': 'United States',
#   'Number': 3},
#  {'Year': '2017',
#   'District Name': 'Sant Andreu',
#   'Neighborhood Name': 'Navas',
#   'Nationality': 'United States',
#   'Number': 6},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': "el Camp de l'Arpa del Clot",
#   'Nationality': 'United States',
#   'Number': 16},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Clot',
#   'Nationality': 'United States',
#   'Number': 17},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Parc i la Llacuna del Poblenou',
#   'Nationality': 'United States',
#   'Number': 17},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'la Vila Olímpica del Poblenou',
#   'Nationality': 'United States',
#   'Number': 12},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Poblenou',
#   'Nationality': 'United States',
#   'Number': 45},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Diagonal Mar i el Front Marítim del Poblenou',
#   'Nationality': 'United States',
#   'Number': 11},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'el Besòs i el Maresme',
#   'Nationality': 'United States',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Provençals del Poblenou',
#   'Nationality': 'United States',
#   'Number': 8},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'Sant Martí de Provençals',
#   'Nationality': 'United States',
#   'Number': 5},
#  {'Year': '2017',
#   'District Name': 'Sant Martí',
#   'Neighborhood Name': 'la Verneda i la Pau',
#   'Nationality': 'United States',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Raval',
#   'Nationality': 'United Kingdom',
#   'Number': 150},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'el Barri Gòtic',
#   'Nationality': 'United Kingdom',
#   'Number': 78},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'la Barceloneta',
#   'Nationality': 'United Kingdom',
#   'Number': 47},
#  {'Year': '2017',
#   'District Name': 'Ciutat Vella',
#   'Neighborhood Name': 'Sant Pere, Santa Caterina i la Ribera',
#   'Nationality': 'United Kingdom',
#   'Number': 118},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'el Fort Pienc',
#   'Nationality': 'United Kingdom',
#   'Number': 39},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'la Sagrada Família',
#   'Nationality': 'United Kingdom',
#   'Number': 37},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Dreta de l'Eixample",
#   'Nationality': 'United Kingdom',
#   'Number': 82},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "l'Antiga Esquerra de l'Eixample",
#   'Nationality': 'United Kingdom',
#   'Number': 59},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': "la Nova Esquerra de l'Eixample",
#   'Nationality': 'United Kingdom',
#   'Number': 57},
#  {'Year': '2017',
#   'District Name': 'Eixample',
#   'Neighborhood Name': 'Sant Antoni',
#   'Nationality': 'United Kingdom',
#   'Number': 52},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'el Poble Sec',
#   'Nationality': 'United Kingdom',
#   'Number': 71},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina del Prat Vermell',
#   'Nationality': 'United Kingdom',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Marina de Port',
#   'Nationality': 'United Kingdom',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Font de la Guatlla',
#   'Nationality': 'United Kingdom',
#   'Number': 9},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Hostafrancs',
#   'Nationality': 'United Kingdom',
#   'Number': 8},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'la Bordeta',
#   'Nationality': 'United Kingdom',
#   'Number': 10},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants - Badal',
#   'Nationality': 'United Kingdom',
#   'Number': 9},
#  {'Year': '2017',
#   'District Name': 'Sants-Montjuïc',
#   'Neighborhood Name': 'Sants',
#   'Nationality': 'United Kingdom',
#   'Number': 22},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'les Corts',
#   'Nationality': 'United Kingdom',
#   'Number': 19},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'la Maternitat i Sant Ramon',
#   'Nationality': 'United Kingdom',
#   'Number': 13},
#  {'Year': '2017',
#   'District Name': 'Les Corts',
#   'Neighborhood Name': 'Pedralbes',
#   'Nationality': 'United Kingdom',
#   'Number': 13},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Vallvidrera, el Tibidabo i les Planes',
#   'Nationality': 'United Kingdom',
#   'Number': 3},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sarrià',
#   'Nationality': 'United Kingdom',
#   'Number': 26},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'les Tres Torres',
#   'Nationality': 'United Kingdom',
#   'Number': 18},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - la Bonanova',
#   'Nationality': 'United Kingdom',
#   'Number': 19},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'Sant Gervasi - Galvany',
#   'Nationality': 'United Kingdom',
#   'Number': 42},
#  {'Year': '2017',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Neighborhood Name': 'el Putxet i el Farró',
#   'Nationality': 'United Kingdom',
#   'Number': 18},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'Vallcarca i els Penitents',
#   'Nationality': 'United Kingdom',
#   'Number': 11},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'el Coll',
#   'Nationality': 'United Kingdom',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Salut',
#   'Nationality': 'United Kingdom',
#   'Number': 15},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': 'la Vila de Gràcia',
#   'Nationality': 'United Kingdom',
#   'Number': 94},
#  {'Year': '2017',
#   'District Name': 'Gràcia',
#   'Neighborhood Name': "el Camp d'en Grassot i Gràcia Nova",
#   'Nationality': 'United Kingdom',
#   'Number': 30},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Baix Guinardó',
#   'Nationality': 'United Kingdom',
#   'Number': 14},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Can Baró',
#   'Nationality': 'United Kingdom',
#   'Number': 5},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Guinardó',
#   'Nationality': 'United Kingdom',
#   'Number': 11},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Font d'en Fargues",
#   'Nationality': 'United Kingdom',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'el Carmel',
#   'Nationality': 'United Kingdom',
#   'Number': 4},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Teixonera',
#   'Nationality': 'United Kingdom',
#   'Number': 5},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Sant Genís dels Agudells',
#   'Nationality': 'United Kingdom',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Montbau',
#   'Nationality': 'United Kingdom',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': "la Vall d'Hebron",
#   'Nationality': 'United Kingdom',
#   'Number': 1},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'la Clota',
#   'Nationality': 'United Kingdom',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Horta-Guinardó',
#   'Neighborhood Name': 'Horta',
#   'Nationality': 'United Kingdom',
#   'Number': 4},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Vilapicina i la Torre Llobeta',
#   'Nationality': 'United Kingdom',
#   'Number': 5},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Porta',
#   'Nationality': 'United Kingdom',
#   'Number': 6},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'el Turó de la Peira',
#   'Nationality': 'United Kingdom',
#   'Number': 7},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Can Peguera',
#   'Nationality': 'United Kingdom',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'la Guineueta',
#   'Nationality': 'United Kingdom',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Canyelles',
#   'Nationality': 'United Kingdom',
#   'Number': 0},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'les Roquetes',
#   'Nationality': 'United Kingdom',
#   'Number': 2},
#  {'Year': '2017',
#   'District Name': 'Nou Barris',
#   'Neighborhood Name': 'Verdun',
#   'Nationality': 'United Kingdom',
#   'Number': 5},
#  ...]

# %%
x = inm_nat.insert_many(inm_nat_clean)
