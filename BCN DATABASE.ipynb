# %%
import pandas as pd
from pymongo import MongoClient
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
url = os.getenv("url")

# %%
url
# Out:
# 'mongodb+srv://admin:admin@bcn.e0wqq.mongodb.net/test'

# %%
client = MongoClient(url)

# %%
client
# Out:
# MongoClient(host=['bcn-shard-00-00.e0wqq.mongodb.net:27017', 'bcn-shard-00-01.e0wqq.mongodb.net:27017', 'bcn-shard-00-02.e0wqq.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-lbgrvb-shard-0', tls=True)

# %%
db = client.get_database("BCN")

# %%
db
# Out:
# Database(MongoClient(host=['bcn-shard-00-00.e0wqq.mongodb.net:27017', 'bcn-shard-00-01.e0wqq.mongodb.net:27017', 'bcn-shard-00-02.e0wqq.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-lbgrvb-shard-0', tls=True), 'BCN')

# %%
inm_nat= list(db["INM.NATIONALITY"].find({}))
data_inm_nat= pd.DataFrame(data = inm_nat)

# %%
data_inm_nat
# Out:
#                             _id  Year District Code District Name  \
# 0      628d907528360e0bbf01e184  2017             1  Ciutat Vella
# 1      628d907528360e0bbf01e185  2017             1  Ciutat Vella
# 2      628d907528360e0bbf01e186  2017             1  Ciutat Vella
# 3      628d907528360e0bbf01e187  2017             1  Ciutat Vella
# 4      628d907528360e0bbf01e188  2017             2      Eixample
# ...                         ...   ...           ...           ...
# 35219  628d908d28360e0bbf026b17  2015            10    Sant Martí
# 35220  628d908d28360e0bbf026b18  2015            10    Sant Martí
# 35221  628d908d28360e0bbf026b19  2015            10    Sant Martí
# 35222  628d908d28360e0bbf026b1a  2015            10    Sant Martí
# 35223  628d908d28360e0bbf026b1b  2015            99     No consta
#
#       Neighborhood Code                      Neighborhood Name  \
# 0                     1                               el Raval
# 1                     2                         el Barri Gòtic
# 2                     3                         la Barceloneta
# 3                     4  Sant Pere, Santa Caterina i la Ribera
# 4                     5                          el Fort Pienc
# ...                 ...                                    ...
# 35219                70                  el Besòs i el Maresme
# 35220                71                Provençals del Poblenou
# 35221                72               Sant Martí de Provençals
# 35222                73                    la Verneda i la Pau
# 35223                99                              No consta
#
#           Nationality  Number
# 0               Spain    1109
# 1               Spain     482
# 2               Spain     414
# 3               Spain     537
# 4               Spain     663
# ...               ...     ...
# 35219  No information       0
# 35220  No information       0
# 35221  No information       0
# 35222  No information       1
# 35223  No information       0
#
# [35224 rows x 8 columns]

# %%
data_inm_nat.head(20)
# Out:
#                          _id  Year District Code   District Name  \
# 0   628d907528360e0bbf01e184  2017             1    Ciutat Vella
# 1   628d907528360e0bbf01e185  2017             1    Ciutat Vella
# 2   628d907528360e0bbf01e186  2017             1    Ciutat Vella
# 3   628d907528360e0bbf01e187  2017             1    Ciutat Vella
# 4   628d907528360e0bbf01e188  2017             2        Eixample
# 5   628d907528360e0bbf01e189  2017             2        Eixample
# 6   628d907528360e0bbf01e18a  2017             2        Eixample
# 7   628d907528360e0bbf01e18b  2017             2        Eixample
# 8   628d907528360e0bbf01e18c  2017             2        Eixample
# 9   628d907528360e0bbf01e18d  2017             2        Eixample
# 10  628d907528360e0bbf01e18e  2017             3  Sants-Montjuïc
# 11  628d907528360e0bbf01e18f  2017             3  Sants-Montjuïc
# 12  628d907528360e0bbf01e190  2017             3  Sants-Montjuïc
# 13  628d907528360e0bbf01e191  2017             3  Sants-Montjuïc
# 14  628d907528360e0bbf01e192  2017             3  Sants-Montjuïc
# 15  628d907528360e0bbf01e193  2017             3  Sants-Montjuïc
# 16  628d907528360e0bbf01e194  2017             3  Sants-Montjuïc
# 17  628d907528360e0bbf01e195  2017             3  Sants-Montjuïc
# 18  628d907528360e0bbf01e196  2017             4       Les Corts
# 19  628d907528360e0bbf01e197  2017             4       Les Corts
#
#    Neighborhood Code                      Neighborhood Name Nationality  \
# 0                  1                               el Raval       Spain
# 1                  2                         el Barri Gòtic       Spain
# 2                  3                         la Barceloneta       Spain
# 3                  4  Sant Pere, Santa Caterina i la Ribera       Spain
# 4                  5                          el Fort Pienc       Spain
# 5                  6                     la Sagrada Família       Spain
# 6                  7                 la Dreta de l'Eixample       Spain
# 7                  8        l'Antiga Esquerra de l'Eixample       Spain
# 8                  9         la Nova Esquerra de l'Eixample       Spain
# 9                 10                            Sant Antoni       Spain
# 10                11                           el Poble Sec       Spain
# 11                12             la Marina del Prat Vermell       Spain
# 12                13                      la Marina de Port       Spain
# 13                14                  la Font de la Guatlla       Spain
# 14                15                            Hostafrancs       Spain
# 15                16                             la Bordeta       Spain
# 16                17                          Sants - Badal       Spain
# 17                18                                  Sants       Spain
# 18                19                              les Corts       Spain
# 19                20             la Maternitat i Sant Ramon       Spain
#
#     Number
# 0     1109
# 1      482
# 2      414
# 3      537
# 4      663
# 5     1181
# 6     1063
# 7     1177
# 8     1593
# 9      883
# 10     826
# 11      23
# 12     574
# 13     264
# 14     410
# 15     434
# 16     605
# 17    1083
# 18    1027
# 19     630

# %%
print(data_inm_nat['Nationality'].unique())
# Out:
# ['Spain' 'Italy' 'China' 'Colombia' 'Venezuela' 'Pakistan' 'Honduras'
#  'France' 'Peru' 'Morocco' 'Argentina' 'Brasil' 'United States'
#  'United Kingdom' 'India' 'Ecuador' 'Russia' 'Germany'
#  'Dominican Republic' 'Mexico' 'Romania' 'Chile' 'Bolivia' 'Portugal'
#  'Ukraine' 'Bangladesh' 'Philippines' 'Paraguay' 'Georgia' 'Netherlands'
#  'Cuba' 'Poland' 'El Salvador' 'Turkey' 'Iran' 'Japan' 'Uruguay' 'Sweden'
#  'Nepal' 'Armenia' 'Belgium' 'Bulgaria' 'Algeria' 'South Korea'
#  'Nicaragua' 'Canada' 'Senegal' 'Switzerland' 'Greece' 'Ireland'
#  'Costa Rica' 'Hungary' 'Egypt' 'Panama' 'Lebanon' 'Nigeria' 'Guatemala'
#  'Israel' 'Austria' 'Denmark' 'Finland' 'Kazakhstan' 'Lithuania' 'Syria'
#  'Vietnam' 'Albania' 'Belarus' 'Australia' 'Czech Republic' 'Croatia'
#  'Equatorial Guinea' 'Serbia' 'Slovakia' 'Norway' 'Tunisia' 'Ghana'
#  'Latvia' 'Moldova' 'Andorra' 'South Africa' 'Slovenia' 'Gambia' 'Camerun'
#  'Indonesia' 'Jordan' 'Azerbaijan' 'Estonia' 'Guinea' 'Iraq'
#  'Saudi Arabia' 'State of Palestine' 'Uzbekistan' 'Cyprus' 'Iceland'
#  'Libya' 'Thailand' 'Mali' 'New Zealand' 'Afghanistan' 'Macedonia'
#  'Angola' 'Ivory Coast' 'Kenya' 'Malaysia' 'Mongolia'
#  'Bosnia and Herzegovina' 'Singapore' 'Luxembourg' 'Sudan' 'Guinea-Bissau'
#  'Tanzania' 'Dominica' 'Kyrgyzstan' 'Congo' 'Mauritania' 'Malta' 'Kuwait'
#  'Montenegro' 'Mozambique' 'Uganda' 'Benin' 'Haiti' 'Trinidad and Tobago'
#  'Myanmar' 'Ethiopia' 'Mauritius' 'Namibia' 'Sierra Leone' 'Qatar'
#  'Sri Lanka' 'Burkina Faso' 'Malawi' 'Togo' 'Eritrea'
#  'United Arab Emirates' 'Cambodja' 'Turkmenistan' 'Chad' 'Zimbabwe'
#  'Botswana' 'Gabon' 'Madagascar' 'Niger' 'Somalia' 'Zambia' 'The Bahamas'
#  'Jamaica' 'Yemen' 'Cape Verde' 'São Tomé and Príncipe'
#  'Antigua and Barbuda' 'Barbados' 'Grenada' 'Bahrain' 'Laos' 'Maldives'
#  'Oman' 'Solomon Islands' 'No information' 'Burundi'
#  'Central African Republic' 'North Korea' 'Guyana' 'Lesotho' 'Liberia'
#  'Puerto Rico' 'Rwanda' 'Saint Kitts and Nevis' 'San Marino' 'Seychelles'
#  'Suriname' 'Tajikistan' 'East Timor' 'Palestinian territories' 'Djibouti'
#  'Swaziland' 'Taiwan']

# %%
data_inm_nat = data_inm_nat.drop(columns=["_id","Neighborhood Code","Neighborhood Name"])

# %%
data_inm_nat.isnull().sum()
# Out:
# Year             0
# District Code    0
# District Name    0
# Nationality      0
# Number           0
# dtype: int64

# %%
type(data_inm_nat["Nationality"])
# Out:
# pandas.core.series.Series

# %%
data_inm_nat["Nationality"]=="No information"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 35219     True
# 35220     True
# 35221     True
# 35222     True
# 35223     True
# Name: Nationality, Length: 35224, dtype: bool

# %%
data_inm_nat[data_inm_nat["Nationality"]=="No information"]
# Out:
#        Year District Code District Name     Nationality  Number
# 11692  2017             1  Ciutat Vella  No information       2
# 11693  2017             1  Ciutat Vella  No information       1
# 11694  2017             1  Ciutat Vella  No information       0
# 11695  2017             1  Ciutat Vella  No information       0
# 11696  2017             2      Eixample  No information       2
# ...     ...           ...           ...             ...     ...
# 35219  2015            10    Sant Martí  No information       0
# 35220  2015            10    Sant Martí  No information       0
# 35221  2015            10    Sant Martí  No information       0
# 35222  2015            10    Sant Martí  No information       1
# 35223  2015            99     No consta  No information       0
#
# [222 rows x 5 columns]

# %%
data_inm_nat.drop(data_inm_nat[data_inm_nat["Nationality"]=="No information"].index, inplace=True)

# %%
data_inm_nat[data_inm_nat["District Name"]=="No consta"]
# Out:
#        Year District Code District Name          Nationality  Number
# 73     2017            99     No consta                Spain       2
# 147    2017            99     No consta                Italy       0
# 221    2017            99     No consta                China       0
# 295    2017            99     No consta             Colombia       0
# 369    2017            99     No consta            Venezuela       0
# ...     ...           ...           ...                  ...     ...
# 34853  2015            99     No consta           Seychelles       0
# 34927  2015            99     No consta         Sierra Leone       0
# 35001  2015            99     No consta            Swaziland       0
# 35075  2015            99     No consta               Taiwan       0
# 35149  2015            99     No consta  Trinidad and Tobago       0
#
# [473 rows x 5 columns]

# %%
data_inm_nat.drop(data_inm_nat[data_inm_nat["District Name"]=="No consta"].index, inplace=True)

# %%
data_inm_nat
# Out:
#        Year District Code District Name          Nationality  Number
# 0      2017             1  Ciutat Vella                Spain    1109
# 1      2017             1  Ciutat Vella                Spain     482
# 2      2017             1  Ciutat Vella                Spain     414
# 3      2017             1  Ciutat Vella                Spain     537
# 4      2017             2      Eixample                Spain     663
# ...     ...           ...           ...                  ...     ...
# 35144  2015            10    Sant Martí  Trinidad and Tobago       0
# 35145  2015            10    Sant Martí  Trinidad and Tobago       0
# 35146  2015            10    Sant Martí  Trinidad and Tobago       0
# 35147  2015            10    Sant Martí  Trinidad and Tobago       0
# 35148  2015            10    Sant Martí  Trinidad and Tobago       0
#
# [34529 rows x 5 columns]

# %%
df_new = data_inm_nat.groupby(by=["Year","District Code","District Name","Nationality"],as_index=False)["Number"].sum()
df_new
# Out:
#       Year District Code District Name  Nationality  Number
# 0     2015             1  Ciutat Vella  Afghanistan       3
# 1     2015             1  Ciutat Vella      Albania      13
# 2     2015             1  Ciutat Vella      Algeria      75
# 3     2015             1  Ciutat Vella      Andorra       1
# 4     2015             1  Ciutat Vella       Angola       0
# ...    ...           ...           ...          ...     ...
# 4725  2017             9   Sant Andreu    Venezuela     192
# 4726  2017             9   Sant Andreu      Vietnam       5
# 4727  2017             9   Sant Andreu        Yemen       0
# 4728  2017             9   Sant Andreu       Zambia       0
# 4729  2017             9   Sant Andreu     Zimbabwe       0
#
# [4730 rows x 5 columns]

# %%
df_new[df_new["Nationality"]=="Spain"]
# Out:
#       Year District Code        District Name Nationality  Number
# 128   2015             1         Ciutat Vella       Spain    2827
# 281   2015            10           Sant Martí       Spain    4913
# 434   2015             2             Eixample       Spain    6894
# 587   2015             3       Sants-Montjuïc       Spain    4747
# 740   2015             4            Les Corts       Spain    2204
# 893   2015             5  Sarrià-Sant Gervasi       Spain    3796
# 1046  2015             6               Gràcia       Spain    3092
# 1199  2015             7       Horta-Guinardó       Spain    3429
# 1352  2015             8           Nou Barris       Spain    3143
# 1505  2015             9          Sant Andreu       Spain    2978
# 1662  2016             1         Ciutat Vella       Spain    2413
# 1824  2016            10           Sant Martí       Spain    4295
# 1986  2016             2             Eixample       Spain    6013
# 2148  2016             3       Sants-Montjuïc       Spain    4071
# 2310  2016             4            Les Corts       Spain    1961
# 2472  2016             5  Sarrià-Sant Gervasi       Spain    3248
# 2634  2016             6               Gràcia       Spain    2621
# 2796  2016             7       Horta-Guinardó       Spain    3033
# 2958  2016             8           Nou Barris       Spain    2880
# 3120  2016             9          Sant Andreu       Spain    2508
# 3280  2017             1         Ciutat Vella       Spain    2542
# 3438  2017            10           Sant Martí       Spain    4726
# 3596  2017             2             Eixample       Spain    6560
# 3754  2017             3       Sants-Montjuïc       Spain    4219
# 3912  2017             4            Les Corts       Spain    1955
# 4070  2017             5  Sarrià-Sant Gervasi       Spain    3425
# 4228  2017             6               Gràcia       Spain    2944
# 4386  2017             7       Horta-Guinardó       Spain    3255
# 4544  2017             8           Nou Barris       Spain    3013
# 4702  2017             9          Sant Andreu       Spain    2713

# %%
df_new.iloc[2]
# Out:
# Year                     2015
# District Code               1
# District Name    Ciutat Vella
# Nationality           Algeria
# Number                     75
# Name: 2, dtype: object

# %%
df_new.head()
# Out:
#    Year District Code District Name  Nationality  Number
# 0  2015             1  Ciutat Vella  Afghanistan       3
# 1  2015             1  Ciutat Vella      Albania      13
# 2  2015             1  Ciutat Vella      Algeria      75
# 3  2015             1  Ciutat Vella      Andorra       1
# 4  2015             1  Ciutat Vella       Angola       0

# %%
import numpy as np

df_new['id'] = np.arange(df_new.shape[0])

# %%
df_new
# Out:
#       Year District Code District Name  Nationality  Number    id
# 0     2015             1  Ciutat Vella  Afghanistan       3     0
# 1     2015             1  Ciutat Vella      Albania      13     1
# 2     2015             1  Ciutat Vella      Algeria      75     2
# 3     2015             1  Ciutat Vella      Andorra       1     3
# 4     2015             1  Ciutat Vella       Angola       0     4
# ...    ...           ...           ...          ...     ...   ...
# 4725  2017             9   Sant Andreu    Venezuela     192  4725
# 4726  2017             9   Sant Andreu      Vietnam       5  4726
# 4727  2017             9   Sant Andreu        Yemen       0  4727
# 4728  2017             9   Sant Andreu       Zambia       0  4728
# 4729  2017             9   Sant Andreu     Zimbabwe       0  4729
#
# [4730 rows x 6 columns]

# %%
df_new
# Out:
#       Year District Code District Name  Nationality  Number    id
# 0     2015             1  Ciutat Vella  Afghanistan       3     0
# 1     2015             1  Ciutat Vella      Albania      13     1
# 2     2015             1  Ciutat Vella      Algeria      75     2
# 3     2015             1  Ciutat Vella      Andorra       1     3
# 4     2015             1  Ciutat Vella       Angola       0     4
# ...    ...           ...           ...          ...     ...   ...
# 4725  2017             9   Sant Andreu    Venezuela     192  4725
# 4726  2017             9   Sant Andreu      Vietnam       5  4726
# 4727  2017             9   Sant Andreu        Yemen       0  4727
# 4728  2017             9   Sant Andreu       Zambia       0  4728
# 4729  2017             9   Sant Andreu     Zimbabwe       0  4729
#
# [4730 rows x 6 columns]

# %%
inm_nat= db["INM.NATION"]

# %%
inm_nat_clean = df_new.to_dict('records')

# %%
inm_nat_clean
# Out:
# [{'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Afghanistan',
#   'Number': 3,
#   'id': 0},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Albania',
#   'Number': 13,
#   'id': 1},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Algeria',
#   'Number': 75,
#   'id': 2},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Andorra',
#   'Number': 1,
#   'id': 3},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Angola',
#   'Number': 0,
#   'id': 4},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Argentina',
#   'Number': 185,
#   'id': 5},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Armenia',
#   'Number': 7,
#   'id': 6},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Australia',
#   'Number': 32,
#   'id': 7},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Austria',
#   'Number': 21,
#   'id': 8},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Azerbaijan',
#   'Number': 13,
#   'id': 9},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Bahrain',
#   'Number': 0,
#   'id': 10},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Bangladesh',
#   'Number': 427,
#   'id': 11},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Barbados',
#   'Number': 0,
#   'id': 12},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Belarus',
#   'Number': 12,
#   'id': 13},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Belgium',
#   'Number': 76,
#   'id': 14},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Benin',
#   'Number': 1,
#   'id': 15},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Bolivia',
#   'Number': 64,
#   'id': 16},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Bosnia and Herzegovina',
#   'Number': 1,
#   'id': 17},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Brasil',
#   'Number': 198,
#   'id': 18},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Bulgaria',
#   'Number': 46,
#   'id': 19},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Burkina Faso',
#   'Number': 0,
#   'id': 20},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Burundi',
#   'Number': 0,
#   'id': 21},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Cambodja',
#   'Number': 0,
#   'id': 22},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Camerun',
#   'Number': 5,
#   'id': 23},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Canada',
#   'Number': 32,
#   'id': 24},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Cape Verde',
#   'Number': 1,
#   'id': 25},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Central African Republic',
#   'Number': 0,
#   'id': 26},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Chile',
#   'Number': 107,
#   'id': 27},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'China',
#   'Number': 161,
#   'id': 28},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Colombia',
#   'Number': 185,
#   'id': 29},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Congo',
#   'Number': 0,
#   'id': 30},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Costa Rica',
#   'Number': 19,
#   'id': 31},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Croatia',
#   'Number': 10,
#   'id': 32},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Cuba',
#   'Number': 39,
#   'id': 33},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Cyprus',
#   'Number': 5,
#   'id': 34},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Czech Republic',
#   'Number': 22,
#   'id': 35},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Denmark',
#   'Number': 38,
#   'id': 36},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Djibouti',
#   'Number': 0,
#   'id': 37},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Dominica',
#   'Number': 1,
#   'id': 38},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Dominican Republic',
#   'Number': 78,
#   'id': 39},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Ecuador',
#   'Number': 106,
#   'id': 40},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Egypt',
#   'Number': 26,
#   'id': 41},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'El Salvador',
#   'Number': 13,
#   'id': 42},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Equatorial Guinea',
#   'Number': 5,
#   'id': 43},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Estonia',
#   'Number': 8,
#   'id': 44},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Ethiopia',
#   'Number': 0,
#   'id': 45},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Finland',
#   'Number': 31,
#   'id': 46},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'France',
#   'Number': 439,
#   'id': 47},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Gabon',
#   'Number': 0,
#   'id': 48},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Gambia',
#   'Number': 11,
#   'id': 49},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Georgia',
#   'Number': 28,
#   'id': 50},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Germany',
#   'Number': 241,
#   'id': 51},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Ghana',
#   'Number': 8,
#   'id': 52},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Greece',
#   'Number': 38,
#   'id': 53},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Grenada',
#   'Number': 0,
#   'id': 54},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Guatemala',
#   'Number': 12,
#   'id': 55},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Guinea',
#   'Number': 8,
#   'id': 56},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Guinea-Bissau',
#   'Number': 0,
#   'id': 57},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Haiti',
#   'Number': 1,
#   'id': 58},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Honduras',
#   'Number': 66,
#   'id': 59},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Hungary',
#   'Number': 39,
#   'id': 60},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Iceland',
#   'Number': 7,
#   'id': 61},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'India',
#   'Number': 359,
#   'id': 62},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Indonesia',
#   'Number': 2,
#   'id': 63},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Iran',
#   'Number': 13,
#   'id': 64},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Iraq',
#   'Number': 4,
#   'id': 65},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Ireland',
#   'Number': 41,
#   'id': 66},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Israel',
#   'Number': 23,
#   'id': 67},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Italy',
#   'Number': 1080,
#   'id': 68},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Ivory Coast',
#   'Number': 2,
#   'id': 69},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Jamaica',
#   'Number': 0,
#   'id': 70},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Japan',
#   'Number': 21,
#   'id': 71},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Jordan',
#   'Number': 1,
#   'id': 72},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Kazakhstan',
#   'Number': 14,
#   'id': 73},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Kenya',
#   'Number': 0,
#   'id': 74},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Kuwait',
#   'Number': 1,
#   'id': 75},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Kyrgyzstan',
#   'Number': 0,
#   'id': 76},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Latvia',
#   'Number': 15,
#   'id': 77},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Lebanon',
#   'Number': 15,
#   'id': 78},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Libya',
#   'Number': 8,
#   'id': 79},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Lithuania',
#   'Number': 17,
#   'id': 80},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Luxembourg',
#   'Number': 0,
#   'id': 81},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Macedonia',
#   'Number': 4,
#   'id': 82},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Madagascar',
#   'Number': 0,
#   'id': 83},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Malaysia',
#   'Number': 1,
#   'id': 84},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Maldives',
#   'Number': 0,
#   'id': 85},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Mali',
#   'Number': 3,
#   'id': 86},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Malta',
#   'Number': 3,
#   'id': 87},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Mauritania',
#   'Number': 11,
#   'id': 88},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Mauritius',
#   'Number': 0,
#   'id': 89},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Mexico',
#   'Number': 185,
#   'id': 90},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Moldova',
#   'Number': 3,
#   'id': 91},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Mongolia',
#   'Number': 1,
#   'id': 92},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Montenegro',
#   'Number': 2,
#   'id': 93},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Morocco',
#   'Number': 400,
#   'id': 94},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Mozambique',
#   'Number': 0,
#   'id': 95},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Namibia',
#   'Number': 1,
#   'id': 96},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Nepal',
#   'Number': 33,
#   'id': 97},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Netherlands',
#   'Number': 133,
#   'id': 98},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'New Zealand',
#   'Number': 2,
#   'id': 99},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Nicaragua',
#   'Number': 8,
#   'id': 100},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Nigeria',
#   'Number': 17,
#   'id': 101},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Norway',
#   'Number': 24,
#   'id': 102},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Oman',
#   'Number': 0,
#   'id': 103},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Pakistan',
#   'Number': 1243,
#   'id': 104},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Palestinian territories',
#   'Number': 1,
#   'id': 105},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Panama',
#   'Number': 14,
#   'id': 106},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Paraguay',
#   'Number': 29,
#   'id': 107},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Peru',
#   'Number': 82,
#   'id': 108},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Philippines',
#   'Number': 338,
#   'id': 109},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Poland',
#   'Number': 75,
#   'id': 110},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Portugal',
#   'Number': 120,
#   'id': 111},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Qatar',
#   'Number': 0,
#   'id': 112},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Romania',
#   'Number': 142,
#   'id': 113},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Russia',
#   'Number': 166,
#   'id': 114},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Rwanda',
#   'Number': 0,
#   'id': 115},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Saint Kitts and Nevis',
#   'Number': 0,
#   'id': 116},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Saudi Arabia',
#   'Number': 7,
#   'id': 117},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Senegal',
#   'Number': 25,
#   'id': 118},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Serbia',
#   'Number': 16,
#   'id': 119},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Seychelles',
#   'Number': 1,
#   'id': 120},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Sierra Leone',
#   'Number': 0,
#   'id': 121},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Singapore',
#   'Number': 4,
#   'id': 122},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Slovakia',
#   'Number': 7,
#   'id': 123},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Slovenia',
#   'Number': 11,
#   'id': 124},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Somalia',
#   'Number': 0,
#   'id': 125},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'South Africa',
#   'Number': 9,
#   'id': 126},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'South Korea',
#   'Number': 37,
#   'id': 127},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Spain',
#   'Number': 2827,
#   'id': 128},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Sri Lanka',
#   'Number': 0,
#   'id': 129},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Sudan',
#   'Number': 1,
#   'id': 130},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Swaziland',
#   'Number': 0,
#   'id': 131},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Sweden',
#   'Number': 112,
#   'id': 132},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Switzerland',
#   'Number': 34,
#   'id': 133},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Syria',
#   'Number': 71,
#   'id': 134},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Taiwan',
#   'Number': 0,
#   'id': 135},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Tanzania',
#   'Number': 2,
#   'id': 136},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Thailand',
#   'Number': 2,
#   'id': 137},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Togo',
#   'Number': 0,
#   'id': 138},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Trinidad and Tobago',
#   'Number': 0,
#   'id': 139},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Tunisia',
#   'Number': 4,
#   'id': 140},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Turkey',
#   'Number': 56,
#   'id': 141},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Turkmenistan',
#   'Number': 0,
#   'id': 142},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Uganda',
#   'Number': 0,
#   'id': 143},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Ukraine',
#   'Number': 116,
#   'id': 144},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'United Kingdom',
#   'Number': 292,
#   'id': 145},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'United States',
#   'Number': 201,
#   'id': 146},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Uruguay',
#   'Number': 32,
#   'id': 147},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Uzbekistan',
#   'Number': 3,
#   'id': 148},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Venezuela',
#   'Number': 146,
#   'id': 149},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Vietnam',
#   'Number': 2,
#   'id': 150},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Yemen',
#   'Number': 0,
#   'id': 151},
#  {'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Zimbabwe',
#   'Number': 0,
#   'id': 152},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Afghanistan',
#   'Number': 2,
#   'id': 153},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Albania',
#   'Number': 10,
#   'id': 154},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Algeria',
#   'Number': 53,
#   'id': 155},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Andorra',
#   'Number': 8,
#   'id': 156},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Angola',
#   'Number': 2,
#   'id': 157},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Argentina',
#   'Number': 168,
#   'id': 158},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Armenia',
#   'Number': 31,
#   'id': 159},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Australia',
#   'Number': 5,
#   'id': 160},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Austria',
#   'Number': 19,
#   'id': 161},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Azerbaijan',
#   'Number': 5,
#   'id': 162},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Bahrain',
#   'Number': 0,
#   'id': 163},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Bangladesh',
#   'Number': 18,
#   'id': 164},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Barbados',
#   'Number': 0,
#   'id': 165},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Belarus',
#   'Number': 8,
#   'id': 166},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Belgium',
#   'Number': 33,
#   'id': 167},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Benin',
#   'Number': 0,
#   'id': 168},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Bolivia',
#   'Number': 147,
#   'id': 169},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Bosnia and Herzegovina',
#   'Number': 6,
#   'id': 170},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Brasil',
#   'Number': 160,
#   'id': 171},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Bulgaria',
#   'Number': 46,
#   'id': 172},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Burkina Faso',
#   'Number': 0,
#   'id': 173},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Burundi',
#   'Number': 0,
#   'id': 174},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Cambodja',
#   'Number': 0,
#   'id': 175},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Camerun',
#   'Number': 4,
#   'id': 176},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Canada',
#   'Number': 19,
#   'id': 177},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Cape Verde',
#   'Number': 0,
#   'id': 178},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Central African Republic',
#   'Number': 0,
#   'id': 179},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Chile',
#   'Number': 82,
#   'id': 180},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'China',
#   'Number': 539,
#   'id': 181},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Colombia',
#   'Number': 204,
#   'id': 182},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Congo',
#   'Number': 2,
#   'id': 183},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Costa Rica',
#   'Number': 9,
#   'id': 184},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Croatia',
#   'Number': 14,
#   'id': 185},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Cuba',
#   'Number': 52,
#   'id': 186},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Cyprus',
#   'Number': 4,
#   'id': 187},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Czech Republic',
#   'Number': 9,
#   'id': 188},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Denmark',
#   'Number': 10,
#   'id': 189},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Djibouti',
#   'Number': 0,
#   'id': 190},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Dominica',
#   'Number': 1,
#   'id': 191},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Dominican Republic',
#   'Number': 136,
#   'id': 192},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Ecuador',
#   'Number': 151,
#   'id': 193},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Egypt',
#   'Number': 34,
#   'id': 194},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'El Salvador',
#   'Number': 25,
#   'id': 195},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Equatorial Guinea',
#   'Number': 2,
#   'id': 196},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Estonia',
#   'Number': 16,
#   'id': 197},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Ethiopia',
#   'Number': 1,
#   'id': 198},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Finland',
#   'Number': 7,
#   'id': 199},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'France',
#   'Number': 232,
#   'id': 200},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Gabon',
#   'Number': 0,
#   'id': 201},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Gambia',
#   'Number': 6,
#   'id': 202},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Georgia',
#   'Number': 84,
#   'id': 203},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Germany',
#   'Number': 106,
#   'id': 204},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Ghana',
#   'Number': 5,
#   'id': 205},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Greece',
#   'Number': 21,
#   'id': 206},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Grenada',
#   'Number': 0,
#   'id': 207},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Guatemala',
#   'Number': 9,
#   'id': 208},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Guinea',
#   'Number': 7,
#   'id': 209},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Guinea-Bissau',
#   'Number': 5,
#   'id': 210},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Haiti',
#   'Number': 0,
#   'id': 211},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Honduras',
#   'Number': 163,
#   'id': 212},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Hungary',
#   'Number': 28,
#   'id': 213},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Iceland',
#   'Number': 0,
#   'id': 214},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'India',
#   'Number': 110,
#   'id': 215},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Indonesia',
#   'Number': 5,
#   'id': 216},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Iran',
#   'Number': 8,
#   'id': 217},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Iraq',
#   'Number': 6,
#   'id': 218},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Ireland',
#   'Number': 19,
#   'id': 219},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Israel',
#   'Number': 7,
#   'id': 220},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Italy',
#   'Number': 539,
#   'id': 221},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Ivory Coast',
#   'Number': 1,
#   'id': 222},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Jamaica',
#   'Number': 0,
#   'id': 223},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Japan',
#   'Number': 17,
#   'id': 224},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Jordan',
#   'Number': 8,
#   'id': 225},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Kazakhstan',
#   'Number': 24,
#   'id': 226},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Kenya',
#   'Number': 1,
#   'id': 227},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Kuwait',
#   'Number': 0,
#   'id': 228},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Kyrgyzstan',
#   'Number': 5,
#   'id': 229},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Latvia',
#   'Number': 11,
#   'id': 230},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Lebanon',
#   'Number': 10,
#   'id': 231},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Libya',
#   'Number': 4,
#   'id': 232},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Lithuania',
#   'Number': 9,
#   'id': 233},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Luxembourg',
#   'Number': 0,
#   'id': 234},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Macedonia',
#   'Number': 0,
#   'id': 235},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Madagascar',
#   'Number': 1,
#   'id': 236},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Malaysia',
#   'Number': 2,
#   'id': 237},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Maldives',
#   'Number': 0,
#   'id': 238},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Mali',
#   'Number': 3,
#   'id': 239},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Malta',
#   'Number': 2,
#   'id': 240},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Mauritania',
#   'Number': 0,
#   'id': 241},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Mauritius',
#   'Number': 0,
#   'id': 242},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Mexico',
#   'Number': 88,
#   'id': 243},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Moldova',
#   'Number': 9,
#   'id': 244},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Mongolia',
#   'Number': 0,
#   'id': 245},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Montenegro',
#   'Number': 1,
#   'id': 246},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Morocco',
#   'Number': 295,
#   'id': 247},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Mozambique',
#   'Number': 0,
#   'id': 248},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Namibia',
#   'Number': 0,
#   'id': 249},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Nepal',
#   'Number': 20,
#   'id': 250},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Netherlands',
#   'Number': 49,
#   'id': 251},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'New Zealand',
#   'Number': 2,
#   'id': 252},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Nicaragua',
#   'Number': 16,
#   'id': 253},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Nigeria',
#   'Number': 8,
#   'id': 254},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Norway',
#   'Number': 9,
#   'id': 255},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Oman',
#   'Number': 0,
#   'id': 256},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Pakistan',
#   'Number': 708,
#   'id': 257},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Palestinian territories',
#   'Number': 7,
#   'id': 258},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Panama',
#   'Number': 7,
#   'id': 259},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Paraguay',
#   'Number': 65,
#   'id': 260},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Peru',
#   'Number': 168,
#   'id': 261},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Philippines',
#   'Number': 17,
#   'id': 262},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Poland',
#   'Number': 66,
#   'id': 263},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Portugal',
#   'Number': 112,
#   'id': 264},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Qatar',
#   'Number': 2,
#   'id': 265},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Romania',
#   'Number': 147,
#   'id': 266},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Russia',
#   'Number': 300,
#   'id': 267},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Rwanda',
#   'Number': 1,
#   'id': 268},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Saint Kitts and Nevis',
#   'Number': 0,
#   'id': 269},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Saudi Arabia',
#   'Number': 5,
#   'id': 270},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Senegal',
#   'Number': 50,
#   'id': 271},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Serbia',
#   'Number': 12,
#   'id': 272},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Seychelles',
#   'Number': 0,
#   'id': 273},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Sierra Leone',
#   'Number': 0,
#   'id': 274},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Singapore',
#   'Number': 1,
#   'id': 275},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Slovakia',
#   'Number': 8,
#   'id': 276},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Slovenia',
#   'Number': 9,
#   'id': 277},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Somalia',
#   'Number': 0,
#   'id': 278},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'South Africa',
#   'Number': 3,
#   'id': 279},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'South Korea',
#   'Number': 23,
#   'id': 280},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Spain',
#   'Number': 4913,
#   'id': 281},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Sri Lanka',
#   'Number': 1,
#   'id': 282},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Sudan',
#   'Number': 1,
#   'id': 283},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Swaziland',
#   'Number': 0,
#   'id': 284},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Sweden',
#   'Number': 34,
#   'id': 285},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Switzerland',
#   'Number': 19,
#   'id': 286},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Syria',
#   'Number': 14,
#   'id': 287},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Taiwan',
#   'Number': 0,
#   'id': 288},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Tanzania',
#   'Number': 0,
#   'id': 289},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Thailand',
#   'Number': 2,
#   'id': 290},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Togo',
#   'Number': 1,
#   'id': 291},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Trinidad and Tobago',
#   'Number': 0,
#   'id': 292},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Tunisia',
#   'Number': 4,
#   'id': 293},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Turkey',
#   'Number': 31,
#   'id': 294},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Turkmenistan',
#   'Number': 1,
#   'id': 295},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Uganda',
#   'Number': 1,
#   'id': 296},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Ukraine',
#   'Number': 201,
#   'id': 297},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'United Kingdom',
#   'Number': 115,
#   'id': 298},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'United States',
#   'Number': 104,
#   'id': 299},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Uruguay',
#   'Number': 36,
#   'id': 300},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Uzbekistan',
#   'Number': 0,
#   'id': 301},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Venezuela',
#   'Number': 184,
#   'id': 302},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Vietnam',
#   'Number': 5,
#   'id': 303},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Yemen',
#   'Number': 0,
#   'id': 304},
#  {'Year': '2015',
#   'District Code': '10',
#   'District Name': 'Sant Martí',
#   'Nationality': 'Zimbabwe',
#   'Number': 0,
#   'id': 305},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Afghanistan',
#   'Number': 1,
#   'id': 306},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Albania',
#   'Number': 7,
#   'id': 307},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Algeria',
#   'Number': 26,
#   'id': 308},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Andorra',
#   'Number': 21,
#   'id': 309},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Angola',
#   'Number': 5,
#   'id': 310},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Argentina',
#   'Number': 295,
#   'id': 311},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Armenia',
#   'Number': 24,
#   'id': 312},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Australia',
#   'Number': 20,
#   'id': 313},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Austria',
#   'Number': 39,
#   'id': 314},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Azerbaijan',
#   'Number': 8,
#   'id': 315},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Bahrain',
#   'Number': 0,
#   'id': 316},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Bangladesh',
#   'Number': 63,
#   'id': 317},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Barbados',
#   'Number': 0,
#   'id': 318},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Belarus',
#   'Number': 19,
#   'id': 319},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Belgium',
#   'Number': 71,
#   'id': 320},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Benin',
#   'Number': 0,
#   'id': 321},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Bolivia',
#   'Number': 173,
#   'id': 322},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Bosnia and Herzegovina',
#   'Number': 4,
#   'id': 323},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Brasil',
#   'Number': 410,
#   'id': 324},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Bulgaria',
#   'Number': 43,
#   'id': 325},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Burkina Faso',
#   'Number': 1,
#   'id': 326},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Burundi',
#   'Number': 0,
#   'id': 327},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Cambodja',
#   'Number': 1,
#   'id': 328},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Camerun',
#   'Number': 5,
#   'id': 329},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Canada',
#   'Number': 49,
#   'id': 330},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Cape Verde',
#   'Number': 0,
#   'id': 331},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Central African Republic',
#   'Number': 0,
#   'id': 332},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Chile',
#   'Number': 169,
#   'id': 333},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'China',
#   'Number': 892,
#   'id': 334},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Colombia',
#   'Number': 483,
#   'id': 335},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Congo',
#   'Number': 1,
#   'id': 336},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Costa Rica',
#   'Number': 24,
#   'id': 337},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Croatia',
#   'Number': 13,
#   'id': 338},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Cuba',
#   'Number': 91,
#   'id': 339},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Cyprus',
#   'Number': 6,
#   'id': 340},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Czech Republic',
#   'Number': 12,
#   'id': 341},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Denmark',
#   'Number': 22,
#   'id': 342},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Djibouti',
#   'Number': 0,
#   'id': 343},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Dominica',
#   'Number': 0,
#   'id': 344},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Dominican Republic',
#   'Number': 130,
#   'id': 345},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Ecuador',
#   'Number': 253,
#   'id': 346},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Egypt',
#   'Number': 34,
#   'id': 347},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'El Salvador',
#   'Number': 49,
#   'id': 348},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Equatorial Guinea',
#   'Number': 2,
#   'id': 349},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Estonia',
#   'Number': 3,
#   'id': 350},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Ethiopia',
#   'Number': 0,
#   'id': 351},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Finland',
#   'Number': 15,
#   'id': 352},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'France',
#   'Number': 516,
#   'id': 353},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Gabon',
#   'Number': 0,
#   'id': 354},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Gambia',
#   'Number': 5,
#   'id': 355},
#  {'Year': '2015',
#   'District Code': '2',
#   'District Name': 'Eixample',
#   'Nationality': 'Georgia',
# ...
#   'Nationality': 'Rwanda',
#   'Number': 1,
#   'id': 880},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Saint Kitts and Nevis',
#   'Number': 0,
#   'id': 881},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Saudi Arabia',
#   'Number': 13,
#   'id': 882},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Senegal',
#   'Number': 8,
#   'id': 883},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Serbia',
#   'Number': 7,
#   'id': 884},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Seychelles',
#   'Number': 0,
#   'id': 885},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Sierra Leone',
#   'Number': 0,
#   'id': 886},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Singapore',
#   'Number': 4,
#   'id': 887},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Slovakia',
#   'Number': 3,
#   'id': 888},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Slovenia',
#   'Number': 2,
#   'id': 889},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Somalia',
#   'Number': 0,
#   'id': 890},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'South Africa',
#   'Number': 3,
#   'id': 891},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'South Korea',
#   'Number': 9,
#   'id': 892},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Spain',
#   'Number': 3796,
#   'id': 893},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Sri Lanka',
#   'Number': 0,
#   'id': 894},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Sudan',
#   'Number': 1,
#   'id': 895},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Swaziland',
#   'Number': 0,
#   'id': 896},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Sweden',
#   'Number': 22,
#   'id': 897},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Switzerland',
#   'Number': 31,
#   'id': 898},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Syria',
#   'Number': 12,
#   'id': 899},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Taiwan',
#   'Number': 0,
#   'id': 900},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Tanzania',
#   'Number': 0,
#   'id': 901},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Thailand',
#   'Number': 4,
#   'id': 902},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Togo',
#   'Number': 0,
#   'id': 903},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Trinidad and Tobago',
#   'Number': 0,
#   'id': 904},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Tunisia',
#   'Number': 1,
#   'id': 905},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Turkey',
#   'Number': 11,
#   'id': 906},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Turkmenistan',
#   'Number': 1,
#   'id': 907},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Uganda',
#   'Number': 0,
#   'id': 908},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Ukraine',
#   'Number': 65,
#   'id': 909},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'United Kingdom',
#   'Number': 88,
#   'id': 910},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'United States',
#   'Number': 218,
#   'id': 911},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Uruguay',
#   'Number': 8,
#   'id': 912},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Uzbekistan',
#   'Number': 2,
#   'id': 913},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Venezuela',
#   'Number': 97,
#   'id': 914},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Vietnam',
#   'Number': 3,
#   'id': 915},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Yemen',
#   'Number': 1,
#   'id': 916},
#  {'Year': '2015',
#   'District Code': '5',
#   'District Name': 'Sarrià-Sant Gervasi',
#   'Nationality': 'Zimbabwe',
#   'Number': 2,
#   'id': 917},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Afghanistan',
#   'Number': 5,
#   'id': 918},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Albania',
#   'Number': 6,
#   'id': 919},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Algeria',
#   'Number': 10,
#   'id': 920},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Andorra',
#   'Number': 6,
#   'id': 921},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Angola',
#   'Number': 0,
#   'id': 922},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Argentina',
#   'Number': 112,
#   'id': 923},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Armenia',
#   'Number': 13,
#   'id': 924},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Australia',
#   'Number': 10,
#   'id': 925},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Austria',
#   'Number': 14,
#   'id': 926},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Azerbaijan',
#   'Number': 5,
#   'id': 927},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Bahrain',
#   'Number': 0,
#   'id': 928},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Bangladesh',
#   'Number': 7,
#   'id': 929},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Barbados',
#   'Number': 0,
#   'id': 930},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Belarus',
#   'Number': 10,
#   'id': 931},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Belgium',
#   'Number': 29,
#   'id': 932},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Benin',
#   'Number': 0,
#   'id': 933},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Bolivia',
#   'Number': 54,
#   'id': 934},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Bosnia and Herzegovina',
#   'Number': 0,
#   'id': 935},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Brasil',
#   'Number': 115,
#   'id': 936},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Bulgaria',
#   'Number': 20,
#   'id': 937},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Burkina Faso',
#   'Number': 0,
#   'id': 938},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Burundi',
#   'Number': 0,
#   'id': 939},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Cambodja',
#   'Number': 0,
#   'id': 940},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Camerun',
#   'Number': 0,
#   'id': 941},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Canada',
#   'Number': 17,
#   'id': 942},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Cape Verde',
#   'Number': 0,
#   'id': 943},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Central African Republic',
#   'Number': 0,
#   'id': 944},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Chile',
#   'Number': 83,
#   'id': 945},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'China',
#   'Number': 135,
#   'id': 946},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Colombia',
#   'Number': 132,
#   'id': 947},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Congo',
#   'Number': 0,
#   'id': 948},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Costa Rica',
#   'Number': 16,
#   'id': 949},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Croatia',
#   'Number': 4,
#   'id': 950},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Cuba',
#   'Number': 23,
#   'id': 951},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Cyprus',
#   'Number': 5,
#   'id': 952},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Czech Republic',
#   'Number': 8,
#   'id': 953},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Denmark',
#   'Number': 2,
#   'id': 954},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Djibouti',
#   'Number': 1,
#   'id': 955},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Dominica',
#   'Number': 0,
#   'id': 956},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Dominican Republic',
#   'Number': 33,
#   'id': 957},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Ecuador',
#   'Number': 64,
#   'id': 958},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Egypt',
#   'Number': 17,
#   'id': 959},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'El Salvador',
#   'Number': 21,
#   'id': 960},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Equatorial Guinea',
#   'Number': 0,
#   'id': 961},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Estonia',
#   'Number': 1,
#   'id': 962},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Ethiopia',
#   'Number': 0,
#   'id': 963},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Finland',
#   'Number': 8,
#   'id': 964},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'France',
#   'Number': 259,
#   'id': 965},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Gabon',
#   'Number': 1,
#   'id': 966},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Gambia',
#   'Number': 5,
#   'id': 967},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Georgia',
#   'Number': 12,
#   'id': 968},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Germany',
#   'Number': 96,
#   'id': 969},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Ghana',
#   'Number': 0,
#   'id': 970},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Greece',
#   'Number': 18,
#   'id': 971},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Grenada',
#   'Number': 0,
#   'id': 972},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Guatemala',
#   'Number': 10,
#   'id': 973},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Guinea',
#   'Number': 6,
#   'id': 974},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Guinea-Bissau',
#   'Number': 0,
#   'id': 975},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Haiti',
#   'Number': 0,
#   'id': 976},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Honduras',
#   'Number': 83,
#   'id': 977},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Hungary',
#   'Number': 27,
#   'id': 978},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Iceland',
#   'Number': 14,
#   'id': 979},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'India',
#   'Number': 124,
#   'id': 980},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Indonesia',
#   'Number': 1,
#   'id': 981},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Iran',
#   'Number': 14,
#   'id': 982},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Iraq',
#   'Number': 1,
#   'id': 983},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Ireland',
#   'Number': 20,
#   'id': 984},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Israel',
#   'Number': 12,
#   'id': 985},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Italy',
#   'Number': 482,
#   'id': 986},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Ivory Coast',
#   'Number': 0,
#   'id': 987},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Jamaica',
#   'Number': 0,
#   'id': 988},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Japan',
#   'Number': 19,
#   'id': 989},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Jordan',
#   'Number': 4,
#   'id': 990},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Kazakhstan',
#   'Number': 6,
#   'id': 991},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Kenya',
#   'Number': 0,
#   'id': 992},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Kuwait',
#   'Number': 0,
#   'id': 993},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Kyrgyzstan',
#   'Number': 1,
#   'id': 994},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Latvia',
#   'Number': 5,
#   'id': 995},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Lebanon',
#   'Number': 10,
#   'id': 996},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Libya',
#   'Number': 3,
#   'id': 997},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Lithuania',
#   'Number': 12,
#   'id': 998},
#  {'Year': '2015',
#   'District Code': '6',
#   'District Name': 'Gràcia',
#   'Nationality': 'Luxembourg',
#   'Number': 0,
#   'id': 999},
#  ...]

# %%
year="2017"
district="Ciutat Vella"
for x in inm_nat_clean:
    res = list(x.find({"Year":year}).find({"District Name":district}))
    print(res)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 3>()
#       2 district="Ciutat Vella"
#       3 for x in inm_nat_clean:
# ----> 4     res = list(x.find({"Year":year}).find({"District Name":district}))
#       5     print(res)
#
# AttributeError: 'dict' object has no attribute 'find'

# %%
x = inm_nat.insert_many(inm_nat_clean)
