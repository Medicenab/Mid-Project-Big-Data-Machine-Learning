# %%
import requests

# %%
BCN=requests.get(f"https://api-midproject.herokuapp.com/all/data").json()

# %%
BCN
# Out:
# [{'_id': {'$oid': '62929be257dc71fdf9618921'},
#   'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Afghanistan',
#   'Number': 3,
#   'id': 0},
#  {'_id': {'$oid': '62929be257dc71fdf9618922'},
#   'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Albania',
#   'Number': 13,
#   'id': 1},
#  {'_id': {'$oid': '62929be257dc71fdf9618923'},
#   'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Algeria',
#   'Number': 75,
#   'id': 2},
#  {'_id': {'$oid': '62929be257dc71fdf9618924'},
#   'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Andorra',
#   'Number': 1,
#   'id': 3},
#  {'_id': {'$oid': '62929be257dc71fdf9618925'},
#   'Year': '2015',
#   'District Code': '1',
#   'District Name': 'Ciutat Vella',
#   'Nationality': 'Angola',
#   'Number': 0,
#   'id': 4},
# ...

# %%
BCN[32]['Nationality']
# Out:
# 'Croatia'

# %%
Ciutat_Vella_2017={}
poblacion=[]
for x in BCN:
    if x["Year"]=="2015":

        if x['District Name']=="Ciutat Vella":
            Ciutat_Vella_2017[x['Nationality']]=(x['Number'])

# %%
Ciutat_Vella_2017
# Out:
# {'Afghanistan': 3,
#  'Albania': 13,
#  'Algeria': 75,
#  'Andorra': 1,
#  'Angola': 0,
#  'Argentina': 185,
#  'Armenia': 7,
#  'Australia': 32,
#  'Austria': 21,
#  'Azerbaijan': 13,
#  'Bahrain': 0,
#  'Bangladesh': 427,
#  'Barbados': 0,
#  'Belarus': 12,
#  'Belgium': 76,
#  'Benin': 1,
#  'Bolivia': 64,
#  'Bosnia and Herzegovina': 1,
#  'Brasil': 198,
#  'Bulgaria': 46,
#  'Burkina Faso': 0,
#  'Burundi': 0,
#  'Cambodja': 0,
#  'Camerun': 5,
#  'Canada': 32,
#  'Cape Verde': 1,
#  'Central African Republic': 0,
#  'Chile': 107,
#  'China': 161,
#  'Colombia': 185,
#  'Congo': 0,
#  'Costa Rica': 19,
#  'Croatia': 10,
#  'Cuba': 39,
#  'Cyprus': 5,
#  'Czech Republic': 22,
#  'Denmark': 38,
#  'Djibouti': 0,
#  'Dominica': 1,
#  'Dominican Republic': 78,
#  'Ecuador': 106,
#  'Egypt': 26,
#  'El Salvador': 13,
#  'Equatorial Guinea': 5,
#  'Estonia': 8,
#  'Ethiopia': 0,
#  'Finland': 31,
#  'France': 439,
#  'Gabon': 0,
#  'Gambia': 11,
#  'Georgia': 28,
#  'Germany': 241,
# ...

# %%
print(type(Ciutat_Vella_2017))
# Out:
# <class 'dict'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,16))
plt.pie(Ciutat_Vella_2017.values(), labels=Ciutat_Vella_2017.keys())
# Out:
# ([<matplotlib.patches.Wedge at 0x7f889e025430>,
# ...
#  [Text(1.0999996394221938, 0.0008906576467228713, 'Afghanistan'),
#   Text(1.099985536854283, 0.0056408076899538, 'Albania'),
#   Text(1.0995413368493148, 0.03176237647944384, 'Algeria'),
#   Text(1.0986585627497865, 0.05430803344417828, 'Andorra'),
#   Text(1.098643865198921, 0.05460455531157768, 'Angola'),
#   Text(1.0945493260420947, 0.10936989010141969, 'Argentina'),
#   Text(1.0874150259758704, 0.1659173326747302, 'Armenia'),
#   Text(1.0856083800196987, 0.17735401103726342, 'Australia'),
#   Text(1.0829604395832282, 0.19286442465551162, 'Austria'),
#   Text(1.0811450526408075, 0.20279392286334894, 'Azerbaijan'),
#   Text(1.0804268660631131, 0.20658602830065756, 'Bahrain'),
#   Text(1.049504431116493, 0.32945477545005586, 'Bangladesh'),
#   Text(1.004658345774066, 0.4479526852989241, 'Barbados'),
#   Text(1.003202269921551, 0.4512041728799143, 'Belarus'),
#   Text(0.9922038427390448, 0.4749016050234754, 'Belgium'),
# ...

# %%
Eixample={}
poblacion=[]
pobla=[]
for x in BCN:
    if x['District Name']=="Eixample":
        if x['Nationality']=="Spain":
            poblacion.append(x['Number'])

        else:
            pobla.append(x['Number'])
            Ciutat_Vella["extranjero"]=(pobla)
poblacion=sum(poblacion)
pobla=sum(pobla)
Eixample["extranjero"]=(pobla)
Eixample["Spain"]=(poblacion)

# %%
Eixample
# Out:
# {'extranjero': 4398, 'Spain': 6560}

# %%
x={'Spain': 2827, 'Pakistan': 1243, 'Italy': 1080, 'France': 439, 'Bangladesh': 427, 'Morocco': 400, 'India': 359, 'Philippines': 338, 'United Kingdom': 292, 'Germany': 241, 'United States': 201, 'Brasil': 198, 'Argentina': 185, 'Colombia': 185, 'Mexico': 185, 'Russia': 166, 'China': 161, 'Venezuela': 146, 'Romania': 142, 'Netherlands': 133, 'Portugal': 120, 'Ukraine': 116, 'Sweden': 112, 'Chile': 107, 'Ecuador': 106, 
'Peru': 82, 'Dominican Republic': 78, 'Belgium': 76, 'Algeria': 75, 'Poland': 75, 'Syria': 71, 'Honduras': 66, 'Bolivia': 64, 'Turkey': 56, 
'Bulgaria': 46, 'Ireland': 41, 'Cuba': 39, 'Hungary': 39, 'Denmark': 38, 'Greece': 38, 'South Korea': 37, 'Switzerland': 34, 'Nepal': 33, 'Australia': 32, 'Canada': 32, 'Uruguay': 32, 'Finland': 31, 'Paraguay': 29, 'Georgia': 28, 'Egypt': 26, 'Senegal': 25, 'Norway': 24, 'Israel': 23, 'Czech Republic': 22, 'Austria': 21, 'Japan': 21, 'Costa Rica': 19, 'Lithuania': 17, 'Nigeria': 17, 'Serbia': 16, 'Latvia': 15, 'Lebanon': 15, 'Kazakhstan': 14, 'Panama': 14, 'Albania': 13, 'Azerbaijan': 13, 'El Salvador': 13, 'Iran': 13, 'Belarus': 12, 'Guatemala': 12, 'Gambia': 11, 'Mauritania': 11, 'Slovenia': 11, 'Croatia': 10, 'South Africa': 9, 'Estonia': 8, 'Ghana': 8, 'Guinea': 8, 'Libya': 8, 'Nicaragua': 8, 'Armenia': 7, 'Iceland': 7, 'Saudi Arabia': 7, 'Slovakia': 7, 'Camerun': 5, 'Cyprus': 5, 'Equatorial Guinea': 5, 'Iraq': 4, 'Macedonia': 4, 'Singapore': 4, 'Tunisia': 4, 'Afghanistan': 3, 'Mali': 3, 'Malta': 3, 'Moldova': 3, 'Uzbekistan': 3, 'Indonesia': 2, 'Ivory Coast': 2, 'Montenegro': 2, 'New Zealand': 2, 'Tanzania': 2, 'Thailand': 2, 'Vietnam': 2, 'Andorra': 1, 'Benin': 1, 'Bosnia and Herzegovina': 1, 'Cape Verde': 1, 'Dominica': 1, 'Haiti': 1, 'Jordan': 1, 'Kuwait': 1, 'Malaysia': 1, 'Mongolia': 1, 'Namibia': 1, 'Palestinian territories': 1, 
'Seychelles': 1, 'Sudan': 1, 'Angola': 0, 'Bahrain': 0, 'Barbados': 0, 'Burkina Faso': 0, 'Burundi': 0, 'Cambodja': 0, 'Central African Republic': 0, 'Congo': 0, 'Djibouti': 0, 'Ethiopia': 0, 'Gabon': 0, 'Grenada': 0, 'Guinea-Bissau': 0, 'Jamaica': 0, 'Kenya': 0, 'Kyrgyzstan': 0, 'Luxembourg': 0, 'Madagascar': 0, 'Maldives': 0, 'Mauritius': 0, 'Mozambique': 0, 'Oman': 0, 'Qatar': 0, 'Rwanda': 0, 'Saint Kitts and Nevis': 0, 'Sierra Leone': 0, 'Somalia': 0, 'Sri Lanka': 0, 'Swaziland': 0, 'Taiwan': 0, 'Togo': 0, 'Trinidad and Tobago': 0, 'Turkmenistan': 0, 'Uganda': 0, 'Yemen': 0, 'Zimbabwe': 0}

# %%
x
# Out:
# {'Afghanistan': 3,
#  'Albania': 13,
#  'Algeria': 75,
#  'Andorra': 1,
#  'Angola': 0,
#  'Argentina': 185,
#  'Armenia': 7,
#  'Australia': 32,
#  'Austria': 21,
#  'Azerbaijan': 13,
#  'Bahrain': 0,
#  'Bangladesh': 427,
#  'Barbados': 0,
#  'Belarus': 12,
#  'Belgium': 76,
#  'Benin': 1,
#  'Bolivia': 64,
#  'Bosnia and Herzegovina': 1,
#  'Brasil': 198,
#  'Bulgaria': 46,
#  'Burkina Faso': 0,
#  'Burundi': 0,
#  'Cambodja': 0,
#  'Camerun': 5,
#  'Canada': 32,
#  'Cape Verde': 1,
#  'Central African Republic': 0,
#  'Chile': 107,
#  'China': 161,
#  'Colombia': 185,
#  'Congo': 0,
#  'Costa Rica': 19,
#  'Croatia': 10,
#  'Cuba': 39,
#  'Cyprus': 5,
#  'Czech Republic': 22,
#  'Denmark': 38,
#  'Djibouti': 0,
#  'Dominica': 1,
#  'Dominican Republic': 78,
#  'Ecuador': 106,
#  'Egypt': 26,
#  'El Salvador': 13,
#  'Equatorial Guinea': 5,
#  'Estonia': 8,
#  'Ethiopia': 0,
#  'Finland': 31,
#  'France': 439,
#  'Gabon': 0,
#  'Gambia': 11,
#  'Georgia': 28,
#  'Germany': 241,
# ...

# %%
import pandas as pd
# Out:
# Afghanistan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 4>()
#       4 for v in x:
#       5     print (v)
# ----> 6     if v >= 70:
#       7         z[v]=k
#       8     if v < 70:
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
plt.figure(figsize=(12,16))
plt.pie(x.values(), labels=x.keys())
# Out:
# ([<matplotlib.patches.Wedge at 0x7f889bd67d60>,
# ...
#  [Text(1.0999996394221938, 0.0008906576467228713, 'Afghanistan'),
#   Text(1.099985536854283, 0.0056408076899538, 'Albania'),
#   Text(1.0995413368493148, 0.03176237647944384, 'Algeria'),
#   Text(1.0986585627497865, 0.05430803344417828, 'Andorra'),
#   Text(1.098643865198921, 0.05460455531157768, 'Angola'),
#   Text(1.0945493260420947, 0.10936989010141969, 'Argentina'),
#   Text(1.0874150259758704, 0.1659173326747302, 'Armenia'),
#   Text(1.0856083800196987, 0.17735401103726342, 'Australia'),
#   Text(1.0829604395832282, 0.19286442465551162, 'Austria'),
#   Text(1.0811450526408075, 0.20279392286334894, 'Azerbaijan'),
#   Text(1.0804268660631131, 0.20658602830065756, 'Bahrain'),
#   Text(1.049504431116493, 0.32945477545005586, 'Bangladesh'),
#   Text(1.004658345774066, 0.4479526852989241, 'Barbados'),
#   Text(1.003202269921551, 0.4512041728799143, 'Belarus'),
#   Text(0.9922038427390448, 0.4749016050234754, 'Belgium'),
# ...
